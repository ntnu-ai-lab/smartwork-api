# %%
import requests

# %%
#  Authentication is enabled and cluster connections are encrypted.

# ℹ️  Password for the elastic user (reset with `bin/elasticsearch-reset-password -u elastic`):
#   UhJ=sDusoDu=8a*JJ-H6

# ℹ️  HTTP CA certificate SHA-256 fingerprint:
#   3e100f2162f9c96b65a6c2ad7494b3646a476ea418b7f583d3e107692af47f9d

# ℹ️  Configure Kibana to use this cluster:
# • Run Kibana and click the configuration link in the terminal when Kibana starts.
# • Copy the following enrollment token and paste it into Kibana in your browser (valid for the next 30 minutes):
#   eyJ2ZXIiOiI4LjguMSIsImFkciI6WyIxNzIuMTguMC4yOjkyMDAiXSwiZmdyIjoiM2UxMDBmMjE2MmY5Yzk2YjY1YTZjMmFkNzQ5NGIzNjQ2YTQ3NmVhNDE4YjdmNTgzZDNlMTA3NjkyYWY0N2Y5ZCIsImtleSI6IjRES0JyNGdCWV94OU1qaXBaWkNHOlE5OTBwczVWVHItdUZMR3htdDFIRlEifQ==

# ℹ️ Configure other nodes to join this cluster:
# • Copy the following enrollment token and start new Elasticsearch nodes with `bin/elasticsearch --enrollment-token <token>` (valid for the next 30 minutes):
#   eyJ2ZXIiOiI4LjguMSIsImFkciI6WyIxNzIuMTguMC4yOjkyMDAiXSwiZmdyIjoiM2UxMDBmMjE2MmY5Yzk2YjY1YTZjMmFkNzQ5NGIzNjQ2YTQ3NmVhNDE4YjdmNTgzZDNlMTA3NjkyYWY0N2Y5ZCIsImtleSI6IjRqS0JyNGdCWV94OU1qaXBaWkNKOkwyRGZ5RnM4UVNTbGZLWVp1NVI0N1EifQ==

# %% [markdown]
# ## new elasticsearch

# %%
from elasticsearch import Elasticsearch




es = Elasticsearch("https://localhost:9400",basic_auth=("elastic","UhJ=sDusoDu=8a*JJ-H6"),verify_certs=False)
es.indices.get_alias(index="*")
# Out:
# /home/stuartgo/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /tmp/ipykernel_1933/4095149589.py:7: ElasticsearchWarning: this request accesses system indices: [.security-7], but in a future major version, direct access to system indices will be prevented by default
#   es.indices.get_alias(index="*")
# ObjectApiResponse({'app_interaction': {'aliases': {}}, 'questionnaire': {'aliases': {}}, 'variables': {'aliases': {}}, 'data_description': {'aliases': {}}, 'education': {'aliases': {}}, 'cases': {'aliases': {}}, 'activity': {'aliases': {}}, 'achievement': {'aliases': {}}, 'notification_settings': {'aliases': {}}, 'app_settings': {'aliases': {}}, 'testing': {'aliases': {}}, 'exercise': {'aliases': {}}, 'baseline': {'aliases': {}}, 'follow_up': {'aliases': {}}, 'feedback': {'aliases': {}}, '.security-7': {'aliases': {'.security': {'is_hidden': True}}}, 'interaction': {'aliases': {}}, 'daily_goals': {'aliases': {}}, 'plan': {'aliases': {}}, 'education_queue': {'aliases': {}}, 'account': {'aliases': {}}, 'notifications': {'aliases': {}}})

# %%
# query={"bool":{"must":[{"exists": {"field": "educationid"}},{"match":{"language":"en"}}]}}
query={"match_all":{}}
res = es.search(index="data_description",query=query,size=900)
# new_education_items=set(map(lambda x: x["_source"]["educationid"] if "educationid" in x["_source"].keys() else None,res["hits"]["hits"]))
print(len(res["hits"]["hits"]))
res["hits"]["hits"]
# Out:
# /home/stuartgo/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 401
# [{'_index': 'data_description',
#   '_id': 'T_tampa_fear',
#   '_score': 1.0,
#   '_ignored': ['explanation.keyword'],
#   '_source': {'questionid': 'T_tampa_fear',
#    'question': 'Hvor ængstelig er du for at rygsmerterne forværres ved fysisk aktivitet eller bevægelse?',
#    'title': 'TAMPA',
#    'type': 'single',
#    'structure': 'horizontal',
#    'language': 'da',
#    'options': [{'option': 'ikke ængstelig',
#      'value': '0',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 1},
#     {'option': '1',
#      'value': '1',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 2},
#     {'option': '2',
#      'value': '2',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 3},
#     {'option': '3',
#      'value': '3',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 4},
#     {'option': '4',
#      'value': '4',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 5},
#     {'option': '5',
#      'value': '5',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 6},
#     {'option': '6',
#      'value': '6',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 7},
#     {'option': '7',
#      'value': '7',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 8},
#     {'option': '8',
#      'value': '8',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 9},
#     {'option': '9',
#      'value': '9',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 10},
#     {'option': 'meget ængstelig',
#      'value': '10',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 11}],
#    'explanation': 'I begyndelsen af studiet eller i en nylig opfølgning, har du indikeret, at du muligvis kunne opleve noget angst i forbindelse med fysisk aktivitet. Baseret på dit svar vil vi i læringsmodulet, give dig information, som kan hjælpe dig med at håndtere din ængstelighed.'}},
#  {'_index': 'data_description',
#   '_id': 'Work_5',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hoe kunt u sociale steun opzoeken',
#    'educationid': 'Work_5',
#    'shortmessage': 'U hoeft zich niet volledig hersteld te voelen voordat u terugkeert naar uw werk. Terugkeren naar de normale routines zal u helpen herstellen.',
#    'longmessage': 'Als uw pijn het moeilijk voor u maakt om uw werk goed uit te kunnen voeren, probeer dan met uw werkgever in gesprek te gaan over werkregelingen. Het zou het aanpassen van uw werktaken of werkuren kunnen betekenen, zodat u in staat bent om te werken terwijl uw lage rug- en nekpijn vermindert, in plaats van u ziek te melden. Op werk blijven of teruggaan naar werkroutines, kan een belangrijk onderdeel zijn een volledig herstel. Thuis blijven van het werk kan een negatief effect hebben op hoe u zich voelt en kan u negatief laten denken.',
#    'link_to_tool': None,
#    'tool': None,
#    'question': 'Moet u volledig hersteld zijn voordat u terugkeert naar uw werk?',
#    'answer': False,
#    'answer_text': 'Het juiste antwoord is nee. Het terugkeren naar uw werk kan u helpen beter te worden. Ga zo snel mogelijk terug naar uw normale routines!',
#    'explanation': 'Dit bericht is bedoeld om u te helpen uw bewustzijn te vergroten over het belang van het hebben van sociale ondersteuning via familie, vrienden en werk. Het hebben van sociale steun is een essentieel onderdeel van het omgaan met de pijn.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'FA Stay active_1',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Eerste hulp bij acute LBNP',
#    'educationid': 'FA Stay active_1',
#    'shortmessage': 'Blijf actief. U kunt eerdere oefeningen terugvinden in uw bibliotheek in de selfBACK app.',
#    'longmessage': 'Bij aanvallen van lage rug- en nekpijn is het advies om actief te blijven. Actief blijven is de sleutel tot uw herstel! Actief blijven betekent zo veel mogelijk bewegen binnen de grenzen van uw pijn, en proberen om elke dag iets meer actief te zijn. Echter, uitdagende oefeningen moeten misschen worden gestopt. In plaats daarvan zou u meer kunnen profiteren van het doen van pijnverlichtende oefeningen.\n',
#    'link_to_tool': 'U kunt pijnverlichtende oefeningen vinden in de Toolbox',
#    'tool': 'Link to pain relief exercises',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Dit bericht is bedoeld om u te begeleiden wanneer u een aanval van uw lage rug- en nekpijn ervaart.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Daily activity_1',
#   '_score': 1.0,
#   '_source': {'headcomponent': 'Pas zelfmanagement toe in uw leven',
#    'educationid': 'Daily activity_1',
#    'shortmessage': 'Pas lichamelijke activiteit toe in uw dagelijkse activiteiten. Stap een halte eerder uit de bus of loop naar uw collega toe in plaats van een e-mail te sturen.',
#    'longmessage': None,
#    'link_to_tool': 'Krijg hulp van het Doelen Stellen hulpmiddel om een \u200b\u200bdoel te stellen voor lichamelijke activiteit!',
#    'tool': 'Goal setting',
#    'question': 'Moet u uw training altijd vooraf plannen?',
#    'answer': False,
#    'answer_text': 'Het juiste antwoord is nee. Lichamelijke activiteit en sport kunnen toegepast worden in uw dagelijks leven. Probeer een oefening te doen tijdens het telefoneren.',
#    'explanation': 'Dit bericht is bedoeld om uw vermogen te vergroten om zelfmanagement van uw lage rug- en nekpijn in te passen in uw leven. Het aannemen van een actieve rol in het verlichten en beheersen van uw pijn zal u een gevoel van empowerment en controle geven.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Stress_2',
#   '_score': 1.0,
#   '_source': {'headcomponent': 'Hoe gedachten LBNP beïnvloeden',
#    'educationid': 'Stress_2',
#    'shortmessage': 'Stress kan de hoeveelheid pijn die u voelt verhogen. Gestrest en gespannen zijn kan leiden tot nog meer pijn.',
#    'longmessage': None,
#    'link_to_tool': 'Verlaag uw stressniveau met behulp van een ontspanningstechniek',
#    'tool': 'Relaxation tool',
#    'question': 'Kan een gestrest gevoel uw lage rug- en nekpijn verlichten?',
#    'answer': False,
#    'answer_text': 'Het juiste antwoord is nee. Stress kan de hoeveelheid pijn die u ervaart verhogen. Bedenk manieren om stress te verminderen als uw onderrug of nek pijn doet.',
#    'explanation': 'Dit bericht is bedoeld om uw kennis te vergroten over hoe stress invloed kan hebben op uw lage rug- en nekpijn. Begrijpen hoe u uw lage rug- en nekpijn met uw geest kan beïnvloeden, kan u helpen uw pijn te beheren.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Changing negative thoughts_7',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hoe gedachten LBNP beïnvloeden',
#    'educationid': 'Changing negative thoughts_7',
#    'shortmessage': 'Blijf bij de feiten en waarheden over uw lage rug- en nekpijn. Zet negatieve gedachten om in positieve. Het zal u helpen om beter om te kunnen gaan met de pijn.',
#    'longmessage': 'Zet een negatieve \'emotioneel redenerende gedachte\' zoals: "Mensen kunnen mijn pijn niet zien, dus ze denken dat ik het misschien verzin. Ik denk dat ze over mij praten" om in een positieve gedachte. Emoties geven u noodzakelijkerwijs niet een realistisch of accuraat gevoel over uw relaties met anderen. Probeer een positieve versie: "Mensen praten over een heleboel dingen - het heeft waarschijnlijk niets met mij te maken. Zelfs als dat het deed, betekent het niet dat ik het me dwars moet laten zitten. Ik weet dat mijn pijn echt is".',
#    'link_to_tool': None,
#    'tool': None,
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Dit bericht is bedoeld om u te informeren over hoe u negatieve gedachten om kunt zetten in positieve gedachten. Positief denken is een copingstrategie voor het managen van lage rug- en nekpijn.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Attitude_2',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hoe gedachten LBNP beïnvloeden',
#    'educationid': 'Attitude_2',
#    'shortmessage': 'Uw instelling is van vitaal belang in het zelf beheren van uw lage rug- en nekpijn. Probeer niet vast te komen zitten door negatieve gedachten. Houd een positieve instelling aan; dit maakt een verschil!',
#    'longmessage': 'Uw houding is alles bij het zelfmanagen van lage rug- en nekpijn. Een positieve houding kan het verschil maken. Probeer niet vast te komen zitten door negatieve gedachten. Word zelfverzekerder door de adviezen te volgen die gegeven worden in de selfBACK app - het zal u helpen om uzelf te helpen. Zie uitdagingen als een manier om sterker te worden en te groeien als persoon. De wereld zal u niet tegenhouden als u uzelf niet tegenhoudt.',
#    'link_to_tool': 'Meer informatie over wat u kunt doen om uzelf te helpen',
#    'tool': 'Encouraging self-management of LBP',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Dit bericht is bedoeld om uw kennis te vergroten over hoe uw gedachten, gevoelens of houding invloed kunnen hebben op uw lage rug- en nekpijn. Begrijpen hoe u uw lage rug- en nekpijn met uw geest kan beïnvloeden, kan u helpen uw pijn te managen.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Anxious_3',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hoe gedachten LBNP beïnvloeden',
#    'educationid': 'Anxious_3',
#    'shortmessage': 'Angst kan uw lage rug- en nekpijn erger maken. Vragen en angsten kunnen zich opstapelen. Probeer ze één voor één aan te pakken. Laat u niet overweldigen door deze vragen/angsten.',
#    'longmessage': 'Angst is een staat van bezorgdheid en nood, vaak over de onzekerheden van de toekomst. U angstig voelen over uw gezondheid en uw pijn is normaal, maar te veel ongerustheid kan leiden tot intense angst wat snel uit de hand kan lopen. Met behulp van een "leiding nemende" houding kunt u de controle over uw angst proberen terug te krijgen. Identificeer uw angsten en pak ze één voor één aan. Identificeer de angsten waarvan u zelf in staat bent om ze aan te pakken en overweeg uw zorgprofessional te benaderen bij angsten die zorgwekkend zijn.',
#    'link_to_tool': 'Meer informatie over wat u kunt doen om uzelf te helpen',
#    'tool': 'Encouraging self-management of LBP',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Dit bericht is bedoeld om uw kennis te vergroten over hoe uw gedachten, gevoelens of houding invloed kunnen hebben op uw lage rug- en nekpijn. Begrijpen hoe u uw lage rug- en nekpijn met uw geest kan beïnvloeden, kan u helpen uw pijn te managen.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Encouragement to SM_5',
#   '_score': 1.0,
#   '_ignored': ['explanation.keyword'],
#   '_source': {'headcomponent': 'Zelf beheren van uw LBNP',
#    'educationid': 'Encouragement to SM_5',
#    'shortmessage': 'Richt u niet op wat u zou kunnen of moeten doen. Kijk vooruit, niet achteruit. Investeer uw tijd en energie in het actief omgaan met uw lage rug- en nekpijn.',
#    'longmessage': 'U zult onvermijdelijk tegen problemen aanlopen die niet gemakkelijk op te lossen zijn. Sommige problemen die gerelateerd zijn aan het zelfmanagen van uw lage rug- en nekpijn kunnen een stap-voor-stap plan nodig hebben om de beste oplossing te vinden.',
#    'link_to_tool': 'Meer informatie over wat u kunt doen om uzelf te helpen',
#    'tool': 'Encouraging self-management of LBP',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Dit bericht is bedoeld om uw kennis te vergroten over wat zelfmanagement van lage rug- en nekpijn is en wat u kunt doen om uzelf te helpen. Het aannemen van een actieve rol in het verlichten en beheersen van uw pijn, zal u ook een gevoel van empowerment en controle geven.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Mind-body connection_2',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword', 'explanation.keyword'],
#   '_source': {'headcomponent': 'Hoe lichaam en geest verbonden zijn',
#    'educationid': 'Mind-body connection_2',
#    'shortmessage': 'Een geest-lichaam benadering kan u helpen vaardigheden te ontwikkelen voor het omgaan met uw lage rug- en nekpijn. Positieve gedachten, gevoelens en gedragingen zullen de pijn verlichten.',
#    'longmessage': 'Het zelf aanpakken van uw lage rug- en nekpijn vereist dat u uw lichaam en geest met elkaar verbindt. Een geest-lichaam benadering helpt u om te leren hoe u gedachtepatronen, gevoelens, en gedragingen die schadelijk zijn voor uw lichaam en geestelijke gezondheid kunt identificeren en veranderen. Deze benadering kan u helpen bij het aanleren van praktische vaardigheden voor het beheren van uw pijn.',
#    'link_to_tool': None,
#    'tool': None,
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Dit bericht is bedoeld om u te helpen begrijpen dat uw lichaam en geest verbonden zijn en dat beide invloed hebben op uw lage rug- en nekpijn. Zich bewust zijn van hoe uw geest uw lage rug- en nekpijn kan beïnvloeden, kan u helpen om te leren leven met uw pijn en om te leren uw pijn te beheren.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Start exercise_8',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Algemene informatie over LBNP',
#    'educationid': 'Start exercise_8',
#    'shortmessage': 'Spierpijn na het sporten is niet gevaarlijk - dit betekent dat uw spieren geactiveerd zijn en dat ze de activiteit leren kennen.',
#    'longmessage': 'Beginnen met sporten is niet eenvoudig. Door het geleidelijk op te bouwen en te luisteren naar de signalen van uw lichaam, verhoogt u uw kans om te blijven sporten. Het starten van een nieuwe bewegingsroutine zal vaak leiden tot meer pijn of spierpijn omdat uw spieren zich aanpassen aan de oefeningen. Dit is volkomen normaal. Hier heeft u een duidelijke keuze: u kunt uitrusten en pijn blijven houden, of u kunt door uw pijn heen werken en ervoor zorgen dat uw onderrug en nek sterker worden.',
#    'link_to_tool': 'Meer informatie over hoe u vooruitgang kunt boeken bij het sporten of het doen van andere lichamelijke activiteiten',
#    'tool': 'Progression Guide',
#    'question': 'Is het normaal om bij het starten van een nieuwe bewegingsroutine, een \u200b\u200bkorte verhoging in spier- en gewrichtspijn te ervaren?',
#    'answer': True,
#    'answer_text': 'Het juiste antwoord is ja. Verhoogde spier- en gewrichtspijn is normaal, uw lichaam is zich aan het aanpassen aan de nieuwe oefening.',
#    'explanation': 'Dit bericht is bedoeld om uw kennis te vergroten over het lichamelijk actief zijn terwijl u lage rug- en nekpijn heeft. Actief blijven en beginnen met sporten zijn belangrijke componenten in het zelfmanagement van lage rug- en nekpijn.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Work_4',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'How to seek social support',
#    'educationid': 'Work_4',
#    'shortmessage': 'Getting back to your normal routines like going to work can be an important part of recovering. Your colleagues may help you stay positive.',
#    'longmessage': "If your pain makes it difficult for you to manage your job, try talking to your employer about work arrangements. It might mean changing your job tasks or hours so you're able to work while your low back and neck continues to get better, rather than calling in sick. Staying at work or getting back into work routines can be an important part of recovering fully. Staying at home from work may have a negative effect on how you feel and feed into negative thinking.  ",
#    'link_to_tool': None,
#    'tool': None,
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'This message is meant to help you increase your awareness about the importance of having social support through family, friends and work. Having social support is an essential part of coping with pain.',
#    'language': 'en',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Goal setting_4',
#   '_score': 1.0,
#   '_ignored': ['explanation.keyword'],
#   '_source': {'headcomponent': 'How to set SMART goals',
#    'educationid': 'Goal setting_4',
#    'shortmessage': 'What do you want to achieve? Find out what really matters to you by setting a goal for yourself. ',
#    'longmessage': None,
#    'link_to_tool': 'Get help to set a goal from the Goal Setting Tool!',
#    'tool': 'Goal setting',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'This message is meant to help you reach your goals related to self-managing your low back and neck pain. Learning practical skills for pain coping will help you in managing and living with low back and neck pain. You might find valuable information and guidance in the tools.',
#    'language': 'en',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'FA Stay active_6',
#   '_score': 1.0,
#   '_source': {'headcomponent': 'First Aid for acute back pain',
#    'educationid': 'FA Stay active_6',
#    'shortmessage': 'The faster you get going the sooner your low back and neck will feel better. Resting for more than a day or two will only slow down your recovery.',
#    'longmessage': None,
#    'link_to_tool': 'Set a goal for being physically active despite your pain flare-up',
#    'tool': 'Goal setting',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'This message is meant to guide you if you experience a flare-up of your low back and neck pain. ',
#    'language': 'en',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Thoughts_1',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'How thoughts affect LBP',
#    'educationid': 'Thoughts_1',
#    'shortmessage': 'If you think positively, you will help your body to unwind and relax. This contributes to feeling better and being less affected by pain.',
#    'longmessage': "If you have pain, it's very common to have negative thoughts that can increase the problem and give the pain a lot of attention. Try challenging your thoughts! When you experience negative thinking about yourself or something, try asking yourself two important questions: 1) Is this thought 100% correct? Try to identify the most objective and true version of this thought and, 2) If I think about this in another manner, how could it change things? Try to re-phrase your thought in a positive way. ",
#    'link_to_tool': 'Learn more about what you can do to help yourself',
#    'tool': 'Encouraging self-management of LBP',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'This message is meant to educate you on how thoughts, feelings or attitude can affect low back and neck pain. ',
#    'language': 'en',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Fear-avoidance_2',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword', 'explanation.keyword'],
#   '_source': {'headcomponent': 'How thoughts affect LBP',
#    'educationid': 'Fear-avoidance_2',
#    'shortmessage': "Don't fear movement or physical activity. Pain doesn't equal harm. Increase how much activity you can do by pacing yourself to make progress.",
#    'longmessage': "The best way to handle fear and tough times is to prepare in advance. Learn as much as possible about your low back and neck pain and how to control it. It's always scarier to face the unknown. Physical activity will benefit you. Build up gradually and listen to your body’s signals. ",
#    'link_to_tool': 'Learn about how to progress when exercising or doing other physical activities',
#    'tool': 'Progression guide',
#    'question': 'Is it true: Increased but brief pain is normal when starting exercising or being physically active?',
#    'answer': True,
#    'answer_text': "The correct answer is yes. It's perfectly normal to experience increased, but short-lasting pain when starting new exercises. ",
#    'explanation': 'This message is meant to increase your knowledge on how your thoughts, feelings or attitude can affect your low back and neck pain. Identifying negative thinking patterns and working on changing them is a coping strategy for managing low back and neck pain.',
#    'language': 'en',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Encouragement to SM_1',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Self-manage your LBP',
#    'educationid': 'Encouragement to SM_1',
#    'shortmessage': 'Self-management means taking care of yourself and your needs, in a healthy way. Learning skills to cope with your low back and neck pain will make life easier.',
#    'longmessage': 'Treatment guidelines for low back and neck pain recommend self-management to reduce pain and improve function. Patient education, reassurance and carrying on with normal activities like going to work and being physically active are important when self-managing. Exercise should also be included (either strength or aerobic exercise), mind-body therapy or a combination. If you’re following the advice given in the selfBACK app, you’re following these guidelines. ',
#    'link_to_tool': 'Learn more about what you can do to help yourself',
#    'tool': 'Encouraging self-management of LBP',
#    'question': 'Does self-management mean consulting with your health-care professional regularly?',
#    'answer': False,
#    'answer_text': 'The correct answer is no. Self-management means taking care of yourself in a healthy way - and asking health-care professionals when needed.',
#    'explanation': 'This message is meant to increase your knowledge on what self-management of low back and neck pain is and what you can do to help yourself. Taking an active role in relieving and controlling your pain will also give you a sense of empowerment and control.',
#    'language': 'en',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'DailyRecordSteps12',
#   '_score': 1.0,
#   '_source': {'achievementid': 'DailyRecordSteps12',
#    'type': 'physical',
#    'title': 'Push It To The Limit',
#    'description_achieved': '12.000 stappen gezet in één dag.',
#    'description': 'Zet 12.000 stappen in één dag.',
#    'image': 'https://dvlxmvtyf5r6m.cloudfront.net/achievements/daily-record-steps-12.png',
#    'language': 'nl',
#    'goal': 12000,
#    'goaltext': 'Voltooid'}},
#  {'_index': 'data_description',
#   '_id': 'main_nlbp_02',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword', 'shortmessage.keyword'],
#   '_source': {'educationid': 'main_nlbp_02',
#    'group_order': 'A',
#    'headcomponent': 'Nyttig å vite om rygg- og nakkesmerter',
#    'caption': 'Årsaker til rygg- og nakkesmerter',
#    'shortmessage': 'Nesten alle vil oppleve rygg- eller nakkesmerter en eller flere ganger i løpet av livet. Ved 80-90 % av tilfellene kan man ikke fastslå den konkrete årsaken til rygg- og nakkesmerter. Selv om smertene kan være sterke, er de sjelden uttrykk for noe alvorlig.',
#    'button': 'Les mer',
#    'longmessage': 'Rygg- og nakkesmerter deles inn i tre grupper etter årsak:\n<ol>\n  <li>Uspesifikke rygg- eller nakkesmerter (ca. 90 %). Årsakene er ofte en kombinasjon av flere faktorer. Smerter kan ha utspring fra flere ulike strukturer i ryggen, slik som ledd, muskler eller annet bløtvev, men uten sikker skade eller årsak. Blant uspesifikke akutte rygg- og nakkesmerter finner vi det som gjerne kalles hekseskudd og kink. Ved tilbakevendende og/eller vedvarende rygg- og nakkesmerter er det i de aller fleste tilfellene ikke mulig å fastslå en sikker vevsskade som årsak til smertene. Selv om den strukturelle årsaken ikke kan fastslås, er det ingen tvil om at det kan være smertefullt.</li>\n  <br>\n  <li>Nerverotsmerter (ca. 10 %). Dette er smerter som kan skyldes tranghet, og i verste fall avklemming av nerverota, i rommet der den passerer ut av ryggsøylen på sin vei ut til armer (fra nakken) og til beina (fra korsryggen). En slik tranghet eller avklemming kan være forårsaket av prolaps og/eller benpåleiringer som tar opp plassen i nerverotkanalen. Typiske symptomer på dette er utstrålende smerter nedenfor kneet hvis det er i korsryggen, og ut i skulder og/eller arm hvis det er i nakken. </li>\n  <br>\n  <li>Annen og sjelden sykdom (svulst, infeksjon, brudd, revmatisk sykdom) (1-5 %). For mer informasjon om dette som årsak, se “Når bør du søke hjelp?</li>\n</ol>',
#    'label_link_to_tool': None,
#    'linked_tool': None,
#    'language': 'nb'}},
#  {'_index': 'data_description',
#   '_id': 'Relaxation_1',
#   '_score': 1.0,
#   '_source': {'headcomponent': 'Hoe kunt u ontspannen',
#    'educationid': 'Relaxation_1',
#    'shortmessage': 'Overdreven gespannen spieren kunnen pijn veroorzaken. Ontspanningstechnieken, zoals een begeleide bodyscan, kunnen spierspanning doen verminderen.',
#    'longmessage': None,
#    'link_to_tool': 'Leid uzelf af van de pijn - probeer het ontspanningshulpmiddel!',
#    'tool': 'Relaxation tool',
#    'question': 'Kunt u zelf iets doen om uw stress of spanning te verminderen?',
#    'answer': True,
#    'answer_text': 'Het juiste antwoord is ja. Ontspanningstechnieken, zoals een bodyscan, kunnen spierspanning verminderen en de pijn in uw onderrug of nek verlichten.',
#    'explanation': 'Dit bericht en de bijbehorende hulpmiddel zijn bedoeld om u te leren hoe u uw lage rug- en nekpijn kunt verlichten met ontspanningstechnieken. Relaxatie is een bekende techniek voor het omgaan met pijn.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'FA Reassurance_2',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Eerste hulp bij acute LBNP',
#    'educationid': 'FA Reassurance_2',
#    'shortmessage': 'Pijnaanvallen zijn normaal. Vind een manier om de plotselinge pijn te beheersen en om vervolgens zo snel mogelijk terug te keren naar uw normale activiteiten.',
#    'longmessage': 'Wanneer u een duidelijke pijnaanval of herhaling van lage rug- of nekpijn ervaart, is het belangrijk te weten dat de behandeling voor dit probleem niet bedoeld is om het te genezen. Het doel is om de pijn te beheren en u te helpen terug te keren naar uw normale activiteit, waaronder ook het zo snel mogelijk volgen van uw eigen zelfmanagement plan in de selfBACK app.',
#    'link_to_tool': 'Meer informatie over lage rug- en nekpijn',
#    'tool': 'Information',
#    'question': 'Zijn pijnaanvallen een teken dat uw onderrug en nek beschadigd raken?',
#    'answer': False,
#    'answer_text': 'Het juiste antwoord is nee. Meestal zijn pijnaanvallen volkomen normaal en gewoon een teken van variatie in uw lage rug- en nekpijn.',
#    'explanation': 'Dit bericht is bedoeld om u te begeleiden wanneer u een aanval van uw lage rug- en nekpijn ervaart.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Thoughts_7',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hoe gedachten LBNP beïnvloeden',
#    'educationid': 'Thoughts_7',
#    'shortmessage': 'Negatieve gevoelens over uw pijn zijn onderdeel van het leven. Door ermee om te gaan, voelt u zich meer aangemoedigd en meer in staat om om te gaan met uw lage rug- en nekpijn.',
#    'longmessage': 'Als u lage rug- en nekpijn heeft, is het heel gebruikelijk om negatieve gedachten te hebben die het probleem vergroten en de pijn veel aandacht geven. Probeer uw gedachten uit te dagen! Als u negatief denkt over uzelf of iets anders, probeer uzelf dan de volgende twee belangrijke vragen af te vragen: 1) Is deze gedachte 100% correct? Probeer de meest objectieve en correcte versie van deze gedachte te vinden, en 2) Als ik op een andere manier hier over nadenk, hoe kan dat dingen veranderen? Probeer uw gedachten op een positieve manier te herformuleren.',
#    'link_to_tool': 'Meer informatie over wat u kunt doen om uzelf te helpen',
#    'tool': 'Encouraging self-management of LBP',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Dit bericht is bedoeld om u te informeren over hoe gedachten, gevoelens of houding lage rug- en nekpijn kunnen beïnvloeden.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Fear-avoidance_1',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword', 'explanation.keyword'],
#   '_source': {'headcomponent': 'Hoe gedachten LBNP beïnvloeden',
#    'educationid': 'Fear-avoidance_1',
#    'shortmessage': 'Wanneer uw lage rug of nek pijn doet, is het normaal om bang te zijn, maar de beste manier om deze angst te overwinnen is door uw gedachten en gedragingen te veranderen.',
#    'longmessage': 'Als uw lichaam niet goed werkt en uw lage rug of nek pijn doet, is het normaal om bang te zijn. U kunt bang zijn dat dingen nooit beter zullen worden en u zult voor de rest van uw leven door de pijn beïnvloed worden. Een manier om deze angst te overwinnen is door uw gedachten en gedragingen te veranderen. Door het opvolgen van het advies en de hulp die gegeven worden in uw educatieve berichten in de selfBACK app, zult u vaardigheden aanleren om uw angst te overwinnen en controle over uw pijn te krijgen.',
#    'link_to_tool': 'Meer informatie over wat u kunt doen om uzelf te helpen',
#    'tool': 'Encouraging self-management of LBP',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Dit bericht is bedoeld om uw kennis te vergroten over hoe uw gedachten, gevoelens of houding invloed kunnen hebben op uw lage rug- en nekpijn. Het identificeren van negatieve denkpatronen en het werken aan het veranderen van hen is een copingstrategie voor het managen van lage rug- en nekpijn.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Reassurance_2',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Algemene informatie over LBNP',
#    'educationid': 'Reassurance_2',
#    'shortmessage': 'Lage rug- en nekpijn kunnen lang duren en af en toe erg slecht voelen, maar het zijn geen progressieve ziekten. Actief en positief blijven helpt!',
#    'longmessage': 'Aanhoudende lage rug- en nekpijn die lang hebben geduurd, zullen helaas waarschijnlijk niet volledig verdwijnen. Het positieve is dat zelfs na een lange tijd met aanhoudende pijn, u beter kunt worden. U moet ook weten dat aanhoudende lage rug- en nekpijn niet geleidelijk aan slechter worden naarmate u ouder wordt.',
#    'link_to_tool': 'Meer informatie over lage rug- en nekpijn',
#    'tool': 'Information',
#    'question': 'Wanneer uw lage rug of nek pijn doet, moet u dan lichamelijke activiteit voorkomen?',
#    'answer': False,
#    'answer_text': 'Het juiste antwoord is nee. Actief blijven is een aanbevolen behandeling, zelfs als uw lage rug of nek pijn doet. Actief zijn kan u helpen om sneller te herstellen.',
#    'explanation': 'Dit bericht is bedoeld om u te helpen uw lage rug- en nekpijn te begrijpen. Meer weten over uw toestand kan het makkelijker maken om de pijn te beheren.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Barrier time_1',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword', 'explanation.keyword'],
#   '_source': {'headcomponent': 'Hvordan håndtere barrierer',
#    'educationid': 'Barrier time_1',
#    'shortmessage': 'La fysisk aktivitet være en del av den daglige rutinen. Gå til jobben eller til butikken, tren mens du ser på TV og bruk trappene istedenfor heisen.',
#    'longmessage': 'Hvis ‘tidsklemma’ begrenser mulighetene for å trene og være fysisk aktiv kan du forsøke å inkludere aktivitet i dine daglige rutiner. Å sykle eller gå istedenfor å kjøre bil på korte turer er en enkelt måte å øke aktiviteten på uten at det tar mye mer tid. Å gå trapper istedenfor å ta heisen er et veldig enkelt tiltak. Litt fysisk aktivitet er mye bedre enn ingenting!\n',
#    'link_to_tool': None,
#    'tool': None,
#    'question': 'Er du alltid nødt til å planlegge treningen din?',
#    'answer': False,
#    'answer_text': 'Det riktige svaret er nei. Fysisk aktivitet og trening kan legges inn i dine daglige rutiner. Prøv for eksempel å gjør øvelser mens du snakker i telefonen eller ser på TV.',
#    'explanation': 'Hensikten med denne beskjeden er å gi deg tips om hvordan du kan håndtere ulike hindringer som stopper deg fra å være mer fysisk aktiv. Å finne gode løsninger på hvordan du kan inkludere fysisk aktivitet i livet ditt vil øke sjansene for at det faktisk skjer.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Family and friends_2',
#   '_score': 1.0,
#   '_source': {'headcomponent': 'Hvordan få støtte fra andre',
#    'educationid': 'Family and friends_2',
#    'shortmessage': 'Ikke la smertene hindre deg i å delta på sosiale aktiviteter - sosial omgang med andre vil også hjelpe deg med å mestre plagene dine. ',
#    'longmessage': 'Smerte kan oppleves som isolerende. Du kan ha nytte av å snakke med partneren eller venner om hvordan det er å leve med plagene dine. Å holde alt for seg selv kan gjøre plagene enda verre. Nyt livet og tilbring tid sammen med venner og familie. ',
#    'link_to_tool': None,
#    'tool': None,
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden er å fremheve hvor viktig det er med sosial støtte fra familie, venner og jobb. Sosial støtte hjelper deg med å håndtere rygg- og nakkeplager på en best mulig måte.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'BT_pain_average',
#   '_score': 1.0,
#   '_source': {'questionid': 'BT_pain_average',
#    'question': 'Angiv din gennemsnitlige grad af lænderygsmerte inden for den sidste uge',
#    'title': 'Lænderygsmerter',
#    'type': 'single',
#    'structure': 'horizontal',
#    'language': 'da',
#    'options': [{'option': 'ingen smerte',
#      'value': '0',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 1},
#     {'option': '1',
#      'value': '1',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 2},
#     {'option': '2',
#      'value': '2',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 3},
#     {'option': '3',
#      'value': '3',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 4},
#     {'option': '4',
#      'value': '4',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 5},
#     {'option': '5',
#      'value': '5',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 6},
#     {'option': '6',
#      'value': '6',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 7},
#     {'option': '7',
#      'value': '7',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 8},
#     {'option': '8',
#      'value': '8',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 9},
#     {'option': '9',
#      'value': '9',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 10},
#     {'option': 'værst mulige smerte',
#      'value': '10',
#      'optiontype': 'radiobutton',
#      'inputtype': 'select',
#      'position': 11}],
#    'explanation': 'Dit svar om smerteintensitet vil hjælpe os med at udvælge relevant information, og hjælpe os med at give dig relevante anbefalinger for træningsmængde og antal skridt for den kommende uge.'}},
#  {'_index': 'data_description',
#   '_id': 'flex_02_06',
#   '_score': 1.0,
#   '_source': {'exerciseid': 'flex_02_06',
#    'title': 'Schouder strekken met behulp van de muur',
#    'type': 'Flexibility',
#    'purpose': 'Deze oefening zal helpen de flexibiliteit van uw bovenlichaam te verhogen, zodat u uw nek en schouders vrijer kunt bewegen',
#    'instruction': 'Ga op ongeveer 1 meter van de muur af staan. Strek uw armen en plaats uw handen zo tegen de muur aan totdat u comfortabel staat. Verlaag uw borst richting de grond. Uw knieën moeten licht gebogen staan. Houd deze positie voor gedurende 20 seconden vast.',
#    'level': 1,
#    'repetitions': 10,
#    'sets': 3,
#    'time': 5,
#    'condition': 'NP',
#    'language': 'nl',
#    'link': ''}},
#  {'_index': 'data_description',
#   '_id': 'ab_05_02',
#   '_score': 1.0,
#   '_ignored': ['instruction.keyword'],
#   '_source': {'exerciseid': 'ab_05_02',
#    'title': 'Dead bug',
#    'type': 'Ab',
#    'purpose': 'Deze oefening richt zich op buikspieren die in combinatie met uw rugspieren uw wervelkolom ondersteunen bij het bewegen, staan \u200b\u200bof tillen',
#    'instruction': 'Ga op uw rug liggen met uw heup en knieën 90 graden gebogen en armen gestrekt richting het plafond. Span uw buikspieren aan en druk uw navel in de richting van uw wervelkolom, dus maak een "platte buik". Beweeg tegelijkertijd uw ene arm achter uw hoofd en het tegenovergestelde been richting de vloer. Ga terug naar de startpositie, en herhaal dit met uw andere arm en been. Voer 10 herhalingen uit om één set te voltooien.',
#    'level': 5,
#    'repetitions': 10,
#    'sets': 3,
#    'time': 5,
#    'condition': 'LBP_NP',
#    'language': 'nl',
#    'link': ''}},
#  {'_index': 'data_description',
#   '_id': 'glut_03_02',
#   '_score': 1.0,
#   '_ignored': ['instruction.keyword'],
#   '_source': {'exerciseid': 'glut_03_02',
#    'title': 'De brug met been strekken',
#    'type': 'Glut',
#    'purpose': 'Deze oefening richt zich op de heup abductie spieren. Deze zijn essentieel voor de ondersteuning van uw onderrug tijdens het lopen en staan.',
#    'instruction': 'Ga op uw rug liggen met uw knieën gebogen en voeten op de grond. Span uw bilspieren aan en til uw bekken en onderrug op, houd deze positie vast. Strek één been met uw tenen wijzend naar het plafond, terwijl u uw knieën bij elkaar houdt, houd deze positie vast voor 2-3 seconden. Ga terug naar de startpositie door uw knie te buigen. Als uw voet de vloer raakt, kunt u uw rug en bekken langzaam laten zakken. Herhaal dit met het andere been.',
#    'level': 3,
#    'repetitions': 10,
#    'sets': 3,
#    'time': 5,
#    'condition': 'LBP_NP',
#    'language': 'nl',
#    'link': ''}},
#  {'_index': 'data_description',
#   '_id': 'glut_01_02',
#   '_score': 1.0,
#   '_source': {'exerciseid': 'glut_01_02',
#    'title': 'Bekken lift',
#    'type': 'Glut',
#    'purpose': 'Deze oefening richt zich op de heup abductie spieren. Deze zijn essentieel voor de ondersteuning van uw onderrug tijdens het lopen en staan.',
#    'instruction': 'Ga op uw rug liggen met uw knieën gebogen en uw voeten op de grond. Span de spieren in uw billen aan en til uw bekken en onderrug op, laat daarna langzaam uw bekken zakken.',
#    'level': 1,
#    'repetitions': 10,
#    'sets': 3,
#    'time': 5,
#    'condition': 'LBP_NP',
#    'language': 'nl',
#    'link': ''}},
#  {'_index': 'data_description',
#   '_id': 'DailyGoalSteps14',
#   '_score': 1.0,
#   '_source': {'achievementid': 'DailyGoalSteps14',
#    'type': 'physical',
#    'title': 'Nå målet ditt',
#    'description_achieved': 'Det daglige målet for antall skritt er nådd 14 ganger.',
#    'description': 'Nå ditt daglige mål for antall skritt 14 ganger.',
#    'image': 'https://dvlxmvtyf5r6m.cloudfront.net/achievements/daily-goal-steps-14.png',
#    'language': 'nb',
#    'goal': 14,
#    'goaltext': 'Fullført'}},
#  {'_index': 'data_description',
#   '_id': 'DailyGoalSteps7',
#   '_score': 1.0,
#   '_source': {'achievementid': 'DailyGoalSteps7',
#    'type': 'physical',
#    'title': 'Nå målet ditt',
#    'description_achieved': 'Det daglige målet for antall skritt er nådd 7 ganger.',
#    'description': 'Nå ditt daglige mål for antall skritt 7 ganger.',
#    'image': 'https://dvlxmvtyf5r6m.cloudfront.net/achievements/daily-goal-steps-7.png',
#    'language': 'nb',
#    'goal': 7,
#    'goaltext': 'Fullført'}},
#  {'_index': 'data_description',
#   '_id': 'EducationalMaterialRead7',
#   '_score': 1.0,
#   '_source': {'achievementid': 'EducationalMaterialRead7',
#    'type': 'educational',
#    'title': "Lest 'Godt å vite'",
#    'description_achieved': "Lest 7 beskjeder i 'Godt å vite'.",
#    'description': "Lest 7 beskjeder i 'Godt å vite'.",
#    'image': 'https://dvlxmvtyf5r6m.cloudfront.net/achievements/educational-read-7.png',
#    'language': 'nb',
#    'goal': 7,
#    'goaltext': 'Fullført.'}},
#  {'_index': 'data_description',
#   '_id': 'EducationalCorrectQuiz25',
#   '_score': 1.0,
#   '_source': {'achievementid': 'EducationalCorrectQuiz25',
#    'type': 'educational',
#    'title': 'Korrekt svar på quiz',
#    'description_achieved': 'Korrekt svar på 25 quiz spørsmål.',
#    'description': 'Korrekt svar på 25 quiz spørsmål',
#    'image': 'https://dvlxmvtyf5r6m.cloudfront.net/achievements/correct-quiz-25.png',
#    'language': 'nb',
#    'goal': 25,
#    'goaltext': 'Fullført.'}},
#  {'_index': 'data_description',
#   '_id': 'RowCompletedSteps25',
#   '_score': 1.0,
#   '_source': {'achievementid': 'RowCompletedSteps25',
#    'type': 'physical',
#    'title': 'Daily Step Commitment',
#    'description_achieved': 'Reached your daily step goal 25 times in a row.',
#    'description': 'Reach your daily step goal 25 times in a row.',
#    'image': 'https://dvlxmvtyf5r6m.cloudfront.net/achievements/row-completed-steps-25.png',
#    'language': 'en',
#    'goal': 25,
#    'goaltext': 'Complete'}},
#  {'_index': 'data_description',
#   '_id': 'Mind-body connection_5',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword', 'explanation.keyword'],
#   '_source': {'headcomponent': 'Hoe lichaam en geest verbonden zijn',
#    'educationid': 'Mind-body connection_5',
#    'shortmessage': 'Hoe u om gaat met uw lage rug- en nekpijn wordt beïnvloed door uw gedachten en ervaringen uit het verleden. Een positieve instelling zorgt ervoor dat u beter om kunt gaan met de pijn.',
#    'longmessage': 'Geloof het of niet; uw gedachten, emoties en ervaringen uit het verleden kunnen invloed hebben op hoeveel pijn u voelt. Ze kunnen een pijnlijke situatie veel erger laten voelen dan dat het is - of veel beter! Uw gedachten kunnen ook invloed hebben op hoe u ervoor kiest om om te gaan met uw pijn, nu en in de toekomst. Dat is de reden waarom u aan uw instelling moet werken om beter om te kunnen gaan met pijn.',
#    'link_to_tool': None,
#    'tool': None,
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Dit bericht is bedoeld om u te helpen begrijpen dat uw lichaam en geest verbonden zijn en dat beide invloed hebben op uw lage rug- en nekpijn. Zich bewust zijn van hoe uw geest uw lage rug- en nekpijn kan beïnvloeden, kan u helpen om te leren leven met uw pijn en om te leren uw pijn te beheren.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Action planning_3',
#   '_score': 1.0,
#   '_ignored': ['explanation.keyword'],
#   '_source': {'headcomponent': 'Hvordan sette seg SMARTe mål',
#    'educationid': 'Action planning_3',
#    'shortmessage': 'Hvis man har et mål uten en plan for hvordan man skal oppnå det, så er jobben bare halvveis gjort. ',
#    'longmessage': 'Når du har flere mål kan det være hensiktsmessig å lage en handlingsplan. En handlingsplan beskriver hvordan du steg-for-steg kan oppnå målene dine. ',
#    'link_to_tool': 'Få hjelp til å planlegge hvordan du når målene dine',
#    'tool': 'Progression Guide',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden er å hjelpe deg med å oppnå målene dine for håndtering av rygg- og nakkeplagene. Å lære praktiske tiltak for å håndtere plagene vil også hjelpe deg til å mestre plagene. Du kan finne verdifull informasjon og veiledning i verktøyene.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Goal setting_3',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword', 'explanation.keyword'],
#   '_source': {'headcomponent': 'Hvordan sette seg SMARTe mål',
#    'educationid': 'Goal setting_3',
#    'shortmessage': 'Å sette seg mål er viktig! Et godt formulert mål bør være spesifikt, målbart, oppnåelig, relevant og tidsbestemt. ',
#    'longmessage': 'Å håndtere rygg- eller nakkeplager på egenhånd kan være krevende og føre til at man mister oversikt over hva man bør prioritere. Å sette seg mål og å nå disse målene vil hjelpe deg med å anerkjenne ferdighetene dine. Målene bør være spesifikke, målbare, oppnåelige, relevante og tidsbestemte. ',
#    'link_to_tool': 'Få hjelp til å sette opp en målsetting ved å bruke tipsene i verktøykassen!',
#    'tool': 'Goal Setting',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden er å hjelpe deg med å oppnå målene dine for håndtering av rygg- og nakkeplagene. Å lære praktiske tiltak for å håndtere plagene vil også hjelpe deg til å mestre plagene. Du kan finne verdifull informasjon og veiledning i verktøyene.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'FA Stay active_2',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Gode råd for akutte ryggsmerter',
#    'educationid': 'FA Stay active_2',
#    'shortmessage': 'Hold deg i aktivitet og beveg deg så mye som mulig uten å gå over smertegrensen. Prøv å øke aktiviteten litt for hver dag. \n\n',
#    'longmessage': 'Selv om du smertene blusser opp igjen kan du fortsatt være fysisk aktiv. Det kan være lurt å forsøke å endre noen av aktivitetene - for eksempel å erstatte spesifikke treningsøvelser med en gåtur. Smertene reduseres raskere hvis du holder deg i aktivitet. Du kan få tips til å regulere og gradvis øke aktivitetsnivået i verktøykassen.',
#    'link_to_tool': None,
#    'tool': None,
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden er å veilede deg hvis du opplever at smertene blusser opp igjen.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Me time_2',
#   '_score': 1.0,
#   '_source': {'headcomponent': 'Håndtering av ryggsmertene i hverdagen',
#    'educationid': 'Me time_2',
#    'shortmessage': 'Lag en liste over aktiviteter som kan bedre plagene dine. Gjør minst én av disse aktivitetene hver dag, selv om det kun er noen få minutter. ',
#    'longmessage': None,
#    'link_to_tool': 'Ta tankene vekk fra smertene - prøv mindfulness som du finner i verktøykassen',
#    'tool': 'Relaxation Tool',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden er å lære deg hvordan man kan regulere og bruke tiden din som et verktøy til å håndtere rygg- og nakkeplagene.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Attitude_1',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hvordan tankene påvirker smertene',
#    'educationid': 'Attitude_1',
#    'shortmessage': 'En positiv innstilling vil gjøre deg i bedre stand til å håndtere plagene dine.',
#    'longmessage': 'Alle har samtaler med seg selv. Hvis du har smerter vil disse samtalene ofte handle om følelser knyttet til smertene. Disse "indre" samtalene kan påvirke hvordan du har det - negative tanker kan føre til negative følelser. Når du sier "Jeg klarer ingenting lenger" vil det sannsynligvis få deg til å føle motløshet. Imidlertid vil du sikkert føle deg bedre og mer oppmuntret hvis du sier: "Jeg vet ikke hvordan dette vil ende, men jeg er optimistisk og jeg vil gjøre et forsøk".        ',
#    'link_to_tool': 'Lær mer om hva du kan gjøre for å hjelpe deg selv',
#    'tool': 'Encouraging self-management of LBP',
# ...
#    'tool': 'Information',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Dit bericht is bedoeld om uw kennis over lage rug- en nekpijn te vergroten en hoe hiermee om te gaan. Het kennen van de mechanismen achter lage rug- en nekpijn kunnen u helpen om te leven met uw pijn en om uw pijn te beheren.',
#    'language': 'nl',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Work_3',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hvordan få støtte fra andre',
#    'educationid': 'Work_3',
#    'shortmessage': 'Å isolere seg hjemme har en negativ effekt på hvordan man føler seg - og på håndteringen av rygg- og nakkeplager.',
#    'longmessage': 'Hvis plagene dine gjør det vanskelig å håndtere arbeidet ditt bør du snakke med arbeidsgiver. Andre måter å organisere arbeidet ditt eller endring av arbeidsoppgaver i en periode kan være hensiktsmessig. Dette kan gi deg muligheten til å håndtere plagene på en bedre måte og redusere sjansen for at du må være borte fra arbeid. Å fortsette å jobbe eller å opprettholde vanlige daglige rutiner kan være viktig for å håndtere og mestre plagene. Å være borte fra jobb kan ha en negativ effekt på hvordan du føler deg og kan i noen tilfeller gi næring til negative tanker. ',
#    'link_to_tool': None,
#    'tool': None,
#    'question': 'Bør du unngå å være på jobb hvis du har rygg- eller nakkesmerter?',
#    'answer': False,
#    'answer_text': 'Det riktige svaret er nei. Å isolere seg vil ha negativ effekt på hvordan du føler deg og gi dårligere prognoser for plagene dine. Snakk med arbeidsgiver om hvordan arbeidsoppgavene kan tilrettelegges.\n\n',
#    'explanation': 'Hensikten med denne beskjeden er å fremheve hvor viktig det er med sosial støtte fra familie, venner og jobb. Sosial støtte hjelper deg med å håndtere rygg- og nakkeplager på en best mulig måte.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Sleep_3',
#   '_score': 1.0,
#   '_source': {'headcomponent': 'Hvordan sove bedre',
#    'educationid': 'Sleep_3',
#    'shortmessage': 'Dårlig søvn og smerter kan forsterke hverandre på en negativ måte. ',
#    'longmessage': 'God søvn vil hjelpe deg å håndtere plagene dine på en bedre måte. Hvis du har problemer med å sove kan du prøve å lage deg en ny kveldsrutine – og sørg for at atmosfæren på soverommet er rolig og avslappende. \n\n',
#    'link_to_tool': 'Du kan bedre søvnen din ved hjelp av tipsene i verktøykassen. Prøv mindfulness!',
#    'tool': 'Sleep Tool',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden og de relaterte verktøyene er å hjelpe deg med å sove bedre. Dårlig søvn og smerter kan bli en ond sirkel som forsterker hverandre. God søvn kan gjøre det lettere å håndtere plagene dine.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Action planning_2',
#   '_score': 1.0,
#   '_ignored': ['explanation.keyword'],
#   '_source': {'headcomponent': 'Hvordan sette seg SMARTe mål',
#    'educationid': 'Action planning_2',
#    'shortmessage': 'Å være proaktiv er en vesentlig del i det å kunne håndtere egne rygg- eller nakkeplager. Lag gjerne en plan for hvordan du kan oppnå målene dine. ',
#    'longmessage': 'Når du har flere mål kan det være hensiktsmessig å lage en handlingsplan. En handlingsplan beskriver hvordan du steg-for-steg kan oppnå målene dine. ',
#    'link_to_tool': 'Få hjelp til å planlegge hvordan du når målene dine',
#    'tool': 'Progression Guide',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden er å hjelpe deg med å oppnå målene dine for håndtering av rygg- og nakkeplagene. Å lære praktiske tiltak for å håndtere plagene vil også hjelpe deg til å mestre plagene. Du kan finne verdifull informasjon og veiledning i verktøyene.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Thoughts_5',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hvordan tankene påvirker smertene',
#    'educationid': 'Thoughts_5',
#    'shortmessage': 'Se opp for katastrofetanker! Negative tanker som utløser nye negative tankerekker vil ikke gjøre deg godt - tvert imot. Tenkt positivt!',
#    'longmessage': 'Katastrofetenkning er en typisk \'feil\' mange med rygg- eller nakkesmerter begår når de tenker på smertene sine. Tanker som opprinnelig er enkle og situasjonsbetinget kan ende opp som katastrofetanker. Et eksempel: "Jeg kommer til å ha en dårlig dag" kan bli til katastrofetanken "Jeg kommer aldri mer til å ha en god dag i resten av mitt liv". Hvis du erkjenner at du har katastrofetanker, så kan du jobbe for å endre de. \n',
#    'link_to_tool': None,
#    'tool': None,
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden er å lære deg hvordan tanker, følelser og innstilling kan påvirke rygg- og nakkeplager.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Thoughts_3',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hvordan tankene påvirker smertene',
#    'educationid': 'Thoughts_3',
#    'shortmessage': 'Gi deg selv et klapp på skulderen for den positive måten du håndterer plagene dine på. Du hjelper deg selv. Vær stolt!\n\n',
#    'longmessage': "I retningslinjene for behandling av rygg- og nakkeplager anbefales det at man selv tar ansvar for å håndtere plagene. For å mestre plagene på en best mulig måte er det viktig med kunnskap og en forståelse av at smertene ikke er tegn på alvorlig sykdom eller skade. Å fortsette med daglige aktiviteter slik som å være på jobb og å være fysisk aktiv virker positivt på rygg- og nakkeplager. Fysisk trening (styrke og/eller utholdenhet), mental trening/mindfulness, eller en kombinasjon er også effektivt for å redusere plagene. Hvis du er fysisk aktiv, trener regelmessig og leser innholdet i 'Godt å vite' følger du de gjeldende anbefalingene.",
#    'link_to_tool': 'Lær mer om hva du kan gjøre for å hjelpe deg selv',
#    'tool': 'Encouraging self-management of LBP',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden er å lære deg hvordan tanker, følelser og innstilling kan påvirke rygg- og nakkeplager.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Distraction_5',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hvordan tankene påvirker smertene',
#    'educationid': 'Distraction_5',
#    'shortmessage': 'Gi deg selv tillatelse og mulighet for å ha det gøy. Gjør noe morsomt for å ta oppmerksomheten bort fra smertene. Dette vil gjøre at du føler mindre smerter.',
#    'longmessage': 'Når du er fysisk aktiv vil hjernen være opptatt av andre ting enn smerter. Hjernen vår kan kun behandle en viss mengde informasjon av gangen. Hvis du har smerter kan du prøve å avlede tankene ved å gjøre en fysisk aktivitet som du setter pris på. Signaler om fysisk aktivitet vil erstatte smertesignalene. Kort sagt: Å gjøre noe som tar tankene vekk fra smertene vil bidra til at du føler mindre smerte.',
#    'link_to_tool': 'Ta tankene vekk fra smertene - prøv mindfulness som du finner i verktøykassen',
#    'tool': 'Relaxation Tool',
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden er å lære deg hvordan du kan snu negative tanker til positive. Å tenke positivt er en mestringsstrategi for å håndtere smertene.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'Changing negative thoughts_10',
#   '_score': 1.0,
#   '_ignored': ['longmessage.keyword'],
#   '_source': {'headcomponent': 'Hvordan tankene påvirker smertene',
#    'educationid': 'Changing negative thoughts_10',
#    'shortmessage': 'Du har et problem, men du ER ikke problemet! Unngå å gjør ting personlig. Dette vil hjelpe deg til å håndtere plagene på en bedre måte.',
#    'longmessage': 'Snu en negativ tanke som: "Familieproblemene våre er min skyld. Uten plagene mine hadde alt vært i orden" til en positiv. Erkjenn at du ikke kan kontrollere alle situasjoner rundt deg og at andre kan velge hvordan de forholder seg til deg og utfordringene dine. En positiv versjon kan være: "Jeg vet at plagene og humøret mitt er utfordrende, men jeg kan ikke ta ansvar for andres følelser. Men jeg kan hjelpe dem med å forstå hva som skjer og hvordan jeg har det."',
#    'link_to_tool': None,
#    'tool': None,
#    'question': None,
#    'answer': False,
#    'answer_text': None,
#    'explanation': 'Hensikten med denne beskjeden er å lære deg hvordan du kan snu negative tanker til positive. Å tenke positivt er en mestringsstrategi for å håndtere smertene.',
#    'language': 'nb',
#    'link': None}},
#  {'_index': 'data_description',
#   '_id': 'general_07',
#   '_score': 1.0,
#   '_source': {'educationid': 'general_07',
#    'group_order': 'H',
#    'headcomponent': 'Vanlige spørsmål',
#    'caption': 'Kan jeg bli lam?',
#    'shortmessage': 'For å bli lam må ryggmargen eller nerver skades. Ryggmargen ligger godt beskyttet inne i ryggsøylens skjelett.',
#    'button': 'Les mer',
#    'longmessage': 'Dersom man får et brudd i ryggsøylen kan ryggmargen bli skadet. Det skal store krefter til for å få brudd i knoklene i ryggen og for at bruddet medfører fare for ryggmargsskade.',
#    'label_link_to_tool': None,
#    'linked_tool': None,
#    'language': 'nb'}},
#  {'_index': 'data_description',
#   '_id': 'ab_06_01',
#   '_score': 1.0,
#   '_source': {'exerciseid': 'ab_06_01',
#    'title': 'Liggende bekkenrotasjon',
#    'function': 'Styrkeøvelser - Nivå 6',
#    'type': 'Ab',
#    'info': 'Disse øvelsene styrker muskulaturen. Følg instruksjonen for hver øvelse. Vi anbefaler at du gjør 3 serier med 5 repetisjoner for hver styrkeøvelse.',
#    'purpose': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene stabiliserer ryggen når man beveger seg, står oppreist eller løfter.',
#    'instruction': 'Ligg på ryggen med armene litt ut fra kroppen. Løft beina opp fra gulvet med tærne pekende mot taket. Aktiver musklene i mage og korsrygg og roter nedre del av kroppen ved å bevege beina fra side til side i en kontrollert bevegelse.  \n',
#    'level': 6,
#    'repetitions': 10,
#    'sets': 3,
#    'time': 5,
#    'condition': 'LBP_NP',
#    'color': '#003283',
#    'group_order': 'D6',
#    'language': 'nb',
#    'link': ''}},
#  {'_index': 'data_description',
#   '_id': 'neck_05_01',
#   '_score': 1.0,
#   '_source': {'exerciseid': 'neck_05_01',
#    'title': 'Liggende armløft',
#    'function': 'Styrkeøvelser - Nivå 5',
#    'type': 'Back',
#    'info': 'Disse øvelsene styrker muskulaturen. Følg instruksjonen for hver øvelse. Vi anbefaler at du gjør 3 serier med 5 repetisjoner for hver styrkeøvelse.',
#    'purpose': 'Denne øvelsen vil styrke nakke- og skuldermusklene dine',
#    'instruction': 'Ligg på magen med armene ut til siden med håndflatene ned mot gulvet. Løft armene opp mot taket slik at skulderbladene samles, uten å løfte på overkroppen. Hold stillingen i 1-2 sekunder før du senker armene igjen.',
#    'level': 5,
#    'repetitions': 10,
#    'sets': 3,
#    'time': 5,
#    'condition': 'NP',
#    'color': '#265195',
#    'group_order': 'D5',
#    'language': 'nb',
#    'link': ''}},
#  {'_index': 'data_description',
#   '_id': 'ab_04_01',
#   '_score': 1.0,
#   '_source': {'exerciseid': 'ab_04_01',
#    'title': 'Liggende bekkenrotasjon',
#    'function': 'Styrkeøvelser - Nivå 4',
#    'type': 'Ab',
#    'info': 'Disse øvelsene styrker muskulaturen. Følg instruksjonen for hver øvelse. Vi anbefaler at du gjør 3 serier med 5 repetisjoner for hver styrkeøvelse.',
#    'purpose': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene stabiliserer ryggen når man beveger seg, står oppreist eller løfter.',
#    'instruction': 'Ligg på ryggen med hofte og knær i 90 grader og armene litt ut fra kroppen. Aktiver musklene i mage og korsrygg og roter nedre del av kroppen ved å bevege knærne fra side til side i en kontrollert bevegelse.  ',
#    'level': 4,
#    'repetitions': 10,
#    'sets': 3,
#    'time': 5,
#    'condition': 'LBP_NP',
#    'color': '#4C6FA8',
#    'group_order': 'D4',
#    'language': 'nb',
#    'link': ''}},
#  {'_index': 'data_description',
#   '_id': 'neck_04_01',
#   '_score': 1.0,
#   '_ignored': ['instruction.keyword'],
#   '_source': {'exerciseid': 'neck_04_01',
#    'title': '"Kaktus"',
#    'function': 'Styrkeøvelser - Nivå 4',
#    'type': 'Back',
#    'info': 'Disse øvelsene styrker muskulaturen. Følg instruksjonen for hver øvelse. Vi anbefaler at du gjør 3 serier med 5 repetisjoner for hver styrkeøvelse.',
#    'purpose': 'Denne øvelsen vil styrke nakke- og skuldermusklene dine',
#    'instruction': 'Stå med litt avstand mellom føttene, lett bøyde knær og overkroppen litt fremoverbøyd. Bøy albuene 90 grader og løft armene ut til siden i skulderhøyde med underarmene parallelt med overkroppen. Strekk armene opp over hodet og tilbake til utgangsposisjonen.',
#    'level': 4,
#    'repetitions': 10,
#    'sets': 3,
#    'time': 5,
#    'condition': 'NP',
#    'color': '#4C6FA8',
#    'group_order': 'D4',
#    'language': 'nb',
#    'link': ''}},
#  {'_index': 'data_description',
#   '_id': 'pain_03_01',
#   '_score': 1.0,
#   '_ignored': ['instruction.keyword', 'info.keyword'],
#   '_source': {'exerciseid': 'pain_03_01',
#    'title': 'Stående bekkenvipp ved vegg',
#    'function': 'Lavterskeløvelser',
#    'type': 'Pain relief',
#    'info': 'Dette er enkle, skånsomme øvelser som gjennomføres med rolige bevegelser. Disse øvelsene er mest aktuelle å bruke på dager med mye smerterhvor vanlig aktivitet kan være utfordrende å få til. Gjennom øvelsene kan dufinne utmer omhvilke bevegelser og stillinger som provoserer smerter ogsom letter på smertene. ',
#    'purpose': 'Små, forsiktige og kontrollerte ryggbevegelser kan lette på akutte ryggsmerter. Det kan også hjelpe deg med å finne ut hvilke bevegelser som provoserer smerter eller som letter på smertene. ',
#    'instruction': 'Stå med ryggen mot en vegg og bekkenet i en nøytral stilling med lett bøyde knær. Vipp bekkenet fremover for å svaie i korsryggen, returner til en nøytral stilling og vipp bekkenet videre bakover slik at korsryggen ligger inntil veggen. Finn området hvor du kan bevege deg smertefritt og merk deg hvor smertegrensen er. Litt bevegelse er bedre enn ingen bevegelse.',
#    'level': 1,
#    'repetitions': 10,
#    'sets': 3,
#    'time': 5,
#    'condition': 'LBP',
#    'color': '#C0D4F0',
#    'group_order': 'A',
#    'language': 'nb',
#    'link': ''}},
#  {'_index': 'data_description',
#   '_id': 'pain_01_02',
#   '_score': 1.0,
#   '_ignored': ['instruction.keyword', 'info.keyword'],
#   '_source': {'exerciseid': 'pain_01_02',
#    'title': 'Bekkenvipp  med bøyde knær',
#    'function': 'Lavterskeløvelser',
#    'type': 'Pain relief',
#    'info': 'Dette er enkle, skånsomme øvelser som gjennomføres med rolige bevegelser. Disse øvelsene er mest aktuelle å bruke på dager med mye smerterhvor vanlig aktivitet kan være utfordrende å få til. Gjennom øvelsene kan dufinne utmer omhvilke bevegelser og stillinger som provoserer smerter ogsom letter på smertene. ',
#    'purpose': 'Små, forsiktige og kontrollerte ryggbevegelser kan lette på akutte ryggsmerter. Det kan også hjelpe deg med å finne ut hvilke bevegelser som provoserer smerter eller som letter på smertene. ',
#    'instruction': 'Ligg på ryggen med bøyde knær, føttene i gulvet og armene hvilende på magen. Vipp bekkenet fremover for å svaie korsryggen, vipp det tilbake til midten og videre bakover helt til korsryggen er i kontakt med gulvet. Kjenn etter hvordan dette påvirker smertene dine. Finn området hvor du kan bevege deg smertefritt og merk deg hvor smertegrensen er. Litt bevegelse er bedre enn ingen bevegelse.',
#    'level': 1,
#    'repetitions': 10,
#    'sets': 3,
#    'time': 5,
#    'condition': 'LBP',
#    'color': '#C0D4F0',
#    'group_order': 'A',
#    'language': 'nb',
#    'link': ''}}]

# %%
def get_user(username):
    res = es.search(index="account", query={'match' : {"_id":username}})
    if not res["hits"]["hits"]:
        return False
    return res.body["hits"]["hits"][0]["_source"]

get_user("stuartFinal2")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 7
#       4         return False
#       5     return res.body["hits"]["hits"][0]["_source"]
# ----> 7 get_user("stuartFinal2")
#
# Cell In[59], line 2, in get_user(username)
#       1 def get_user(username):
# ----> 2     res = es.search(index="account", query={'match' : {"_id":username}})
#       3     if not res["hits"]["hits"]:
#       4         return False
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/elasticsearch5/client/utils.py:73, in query_params.<locals>._wrapper.<locals>._wrapped(*args, **kwargs)
#      71     if p in kwargs:
#      72         params[p] = kwargs.pop(p)
# ---> 73 return func(*args, params=params, **kwargs)
#
# TypeError: search() got an unexpected keyword argument 'query'

# %%
res = es.search(index="account", query={'match_all' : {}},size=100)
res.body
# list(map(lambda x: x["_id"],res["hits"]["hits"]))
# Out:
# /home/stuartgo/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'took': 4,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 134, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'account',
#     '_id': 'r-pioenroos',
#     '_score': 1.0,
#     '_source': {'userid': 'r-pioenroos',
#      'password': '$2a$11$ahzU2hbTzT54VVzuWWtCveyAqNm2blLPU0Emo85IyBPSl3ERfNV4K',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-zonnebloem',
#     '_score': 1.0,
#     '_source': {'userid': 'r-zonnebloem',
#      'password': '$2a$11$RueeCDQRY3sDGBnSTvmQWum5XoLmbf32CWgLIheYnlVsnOnXrHY8e',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-tone',
#     '_score': 1.0,
#     '_source': {'userid': 't-tone',
#      'password': '$2a$11$F4pSWbaKFmC8m82/L9/7FOtwhwLWKd6cKfjXhQZ5EKXEx1PZXi7lu',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-kerstin',
#     '_score': 1.0,
#     '_source': {'userid': 'i-kerstin',
#      'password': '$2a$11$sVwvOAr24ni0wu1g8o02jOyVsWIQkzQK75Aw7CQXoF5uUig2PNryC',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-laurier',
#     '_score': 1.0,
#     '_source': {'userid': 'r-laurier',
#      'password': '$2a$11$6GWMdj0CQD4CttUL0hnKN.pd11nu6ZAmv1zkCveyqcE4VlAfxaKA6',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-anncecilie',
#     '_score': 1.0,
#     '_source': {'userid': 'e-anncecilie',
#      'password': '$2a$11$BySLhqnaz0BzvBS9pfkme.QaJ5WR2xeNs/qbGqW7boQfRsuQjo.PG',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-kirill-nb',
#     '_score': 1.0,
#     '_source': {'userid': 'i-kirill-nb',
#      'password': '$2a$11$bugk22kjJN67d41Fgp7Teel9OGfHbpgGEVgJgGebKarsl0WqlRnYi',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-anne',
#     '_score': 1.0,
#     '_source': {'userid': 't-anne',
#      'password': '$2a$11$aB4mg4T/Yxb04EiHy4wYeuaaq6Gm37vCMeDMZgilZdxtvPrz0RFL.',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-test-ilya',
#     '_score': 1.0,
#     '_source': {'userid': 'i-test-ilya',
#      'password': '$2a$11$JIJgBdkAEGKr/zvCevtBP.MExSiDo88Z8ZWO7UyJL5XRXgdn0w5uO',
#      'country': 'en',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-jasmijn',
#     '_score': 1.0,
#     '_source': {'userid': 'r-jasmijn',
#      'password': '$2a$11$i/nv2whfEUsVJwgglaVF9OblT.oxVy1vUKI5bv9uqbm7O5oj6RYR.',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-silje',
#     '_score': 1.0,
#     '_source': {'userid': 't-silje',
#      'password': '$2a$11$l0dxkmVcZi4wS1Do5fTfxOrQVVI74WYRP7xPBZVf0w7B/vdVbGl8.',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'pau4615',
#     '_score': 1.0,
#     '_source': {'userid': 'pau4615',
#      'password': '$2a$11$x7UcMKlF.9V7xsMQj4vL.uMToWRuNrBoWqlfQUHVREQ0vUJ3Vm25u',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_WEB_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'kerstin_ip',
#     '_score': 1.0,
#     '_source': {'userid': 'kerstin_ip',
#      'password': '$2a$11$/PHgNIlYSyrwK6Q4/q/3neXHygfcW.PofWJUBOp.dtKxOaCBu3fKS',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'researcher',
#     '_score': 1.0,
#     '_source': {'userid': 'researcher',
#      'password': '$2a$11$V0pg./H8.W3DSN9vxj6DXuB1R3rQa2LnHzf/SOk3yUZ7e.uf7S7uG',
#      'country': 'en',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_RESEARCHER', 'ACTUATOR'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'test-user',
#     '_score': 1.0,
#     '_source': {'userid': 'test-user',
#      'password': '$2a$11$nCVsKyhcyLdzUJwI1Z.s6u3rec82xqSHs8LtMnY0hdd7oG/qwfblC',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-aster',
#     '_score': 1.0,
#     '_source': {'userid': 'r-aster',
#      'password': '$2a$11$nlG.Hd8o6D0/LscuyheKXe7Z7ayI2QqMbh2jSJ0Msw.ofj4udRMM6',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-zwanenbloem',
#     '_score': 1.0,
#     '_source': {'userid': 'r-zwanenbloem',
#      'password': '$2a$11$HeRV2hmo3HkXLp1m1/AA2OfcdUWZAhPNHi7Bnm2J3iTIkoo87yrGa',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-test',
#     '_score': 1.0,
#     '_source': {'userid': 'i-test',
#      'password': '$2a$11$u3SfA6OwwUfo7.v0.KD.mOTcOWG5ckA/vvo2cpcy1f3g54oKyza3W',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_WEB_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-siri',
#     '_score': 1.0,
#     '_source': {'userid': 't-siri',
#      'password': '$2a$11$vEWwv8uEMhTVL47AF8lySORZhM5a6iknzmWQY5gQ2gK0iaLwpOtBq',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-hortensia',
#     '_score': 1.0,
#     '_source': {'userid': 'r-hortensia',
#      'password': '$2a$11$mcO3OQksT1/DASbEoEsKU.6n4SdpVOg5C1b27YSgyYuINK/CIXgH6',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-ilya',
#     '_score': 1.0,
#     '_source': {'userid': 't-ilya',
#      'password': '$2a$11$NzjvCHQNdLpvpJ.wPfmT7enBEVSF8buZhhMtB4EHT/6wu9O2gVMS6',
#      'country': 'en',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-marian',
#     '_score': 1.0,
#     '_source': {'userid': 'i-marian',
#      'password': '$2a$11$7RZYMzSUkckU5.ChMr9czuUC8QGOcQ8NiVwZGoXvabPI6yViyc4o.',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'trx5',
#     '_score': 1.0,
#     '_source': {'userid': 'trx5',
#      'password': '$2a$11$mcj9O9mrVUxfZyQkyBt4o.WlM4N.OSUpPCa2vfHri66v5trJJT/ue',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'UwAGtIgB0ZzfAYNPiL3_',
#     '_score': 1.0,
#     '_source': {'userid': 'stuartgo',
#      'password': '$2b$12$phrVybcm8uyeTl9D/cdYoeZxiOHsjddjitMoYWv8lMVu9bMuY1L2a',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'stuartgsso',
#     '_score': 1.0,
#     '_source': {'userid': 'stuartgo',
#      'password': '$2b$12$phrVybcm8uyeTl9D/cdYoeZxiOHsjddjitMoYWv8lMVu9bMuY1L2a',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-line',
#     '_score': 1.0,
#     '_source': {'userid': 'stuartgo',
#      'password': 'test',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': 'ROLE_USER',
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-test-2',
#     '_score': 1.0,
#     '_source': {'userid': 'stuartgo',
#      'password': 'test',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': 'ROLE_USER',
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-anjer',
#     '_score': 1.0,
#     '_source': {'userid': 'r-anjer',
#      'password': '$2a$11$HHZtQZyum0CSzCSjVZn9OOY7.y50kubCSw7yq8oKczNUYUDU4Eon6',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-anemoon',
#     '_score': 1.0,
#     '_source': {'userid': 'r-anemoon',
#      'password': '$2a$11$FOt6VUiCWkU1XjtSSWmrPObVRSyvQBbVvrAwMZlzykvtgeH4Emr8O',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-nl-prof8',
#     '_score': 1.0,
#     '_source': {'userid': 'e-nl-prof8',
#      'password': '$2a$11$Ro9a697qSGHy8hrWswp4Ou4rnny/KMW90ZX7ICttlNNeXianVOeqS',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'trx2',
#     '_score': 1.0,
#     '_source': {'userid': 'trx2',
#      'password': '$2a$11$mcj9O9mrVUxfZyQkyBt4o.WlM4N.OSUpPCa2vfHri66v5trJJT/ue',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'trx1',
#     '_score': 1.0,
#     '_source': {'userid': 'trx1',
#      'password': '$2a$11$mcj9O9mrVUxfZyQkyBt4o.WlM4N.OSUpPCa2vfHri66v5trJJT/ue',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'ben6051',
#     '_score': 1.0,
#     '_source': {'userid': 'ben6051',
#      'password': '$2a$11$PAf44y6Fiy.H7VqQi8wquegd1KBjQMIrRMPovyWagVOvcCnvs49DS',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-svein',
#     '_score': 1.0,
#     '_source': {'userid': 't-svein',
#      'password': '$2a$11$t7je2vfteao3E0roKFKnreFji4zV3mi.T2pSc3HxpeNE40kx7iRXq',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-nl-prof4',
#     '_score': 1.0,
#     '_source': {'userid': 'e-nl-prof4',
#      'password': '$2a$11$s5Z3Xl4QZWgjGOPiwsoypeTGPRas3GA.EceDwfAvBcYWdUNfkx9X2',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-lars',
#     '_score': 1.0,
#     '_source': {'userid': 't-lars',
#      'password': '$2a$11$B76BBuo9Sxc.t5jvHLDs3eZmVGWaKfvL2gQOwI4Olo.qpv2chaH82',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'trx4',
#     '_score': 1.0,
#     '_source': {'userid': 'trx4',
#      'password': '$2a$11$mcj9O9mrVUxfZyQkyBt4o.WlM4N.OSUpPCa2vfHri66v5trJJT/ue',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'jan3909',
#     '_score': 1.0,
#     '_source': {'userid': 'jan3909',
#      'password': '$2a$11$Mz6dOt2js5/mNukxidfzVelm98AemSlpWP1yBHi5L6oLDRFpMN3AC',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'test-app',
#     '_score': 1.0,
#     '_source': {'userid': 'test-app',
#      'password': '$2a$11$nCVsKyhcyLdzUJwI1Z.s6u3rec82xqSHs8LtMnY0hdd7oG/qwfblC',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'test-app-neck',
#     '_score': 1.0,
#     '_source': {'userid': 'test-app-neck',
#      'password': '$2a$11$B2oM5p.abx9qbTy8F2bM/.hbm0zOjDMlfB9M.Ago/JDWY.h7OUMAS',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'test-web-activate',
#     '_score': 1.0,
#     '_source': {'userid': 'test-web-activate',
#      'password': '$2a$11$xSwLUGss068M1YXF6UGRx.xLc.y26D7EDRpI3yef/C5ohCz9xA1BO',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_WEB_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-siri',
#     '_score': 1.0,
#     '_source': {'userid': 'i-siri',
#      'password': '$2a$11$hcyqPJahOqMMGZG/KZZAQuhyu/oeDSyLzRuVGlqn2kByiOU5qjJ5u',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-klaver',
#     '_score': 1.0,
#     '_source': {'userid': 'r-klaver',
#      'password': '$2a$11$OLzJ9JA/I.x1iKhSW4w3/u15rlFRH1ZoK0cW1LGFBSQizbfRCuT2a',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-ilya',
#     '_score': 1.0,
#     '_source': {'userid': 'i-ilya',
#      'password': '$2a$11$u3SfA6OwwUfo7.v0.KD.mOTcOWG5ckA/vvo2cpcy1f3g54oKyza3W',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-kerstin-nl',
#     '_score': 1.0,
#     '_source': {'userid': 'i-kerstin-nl',
#      'password': '$2a$11$sVwvOAr24ni0wu1g8o02jOyVsWIQkzQK75Aw7CQXoF5uUig2PNryC',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'a-kba1',
#     '_score': 1.0,
#     '_source': {'userid': 'a-kba1',
#      'password': '$2a$11$mcj9O9mrVUxfZyQkyBt4o.WlM4N.OSUpPCa2vfHri66v5trJJT/ue',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-ingunn',
#     '_score': 1.0,
#     '_source': {'userid': 't-ingunn',
#      'password': '$2a$11$6eE5nab0dMceL49oCWHZieP8KH9vkgwzNnihcZco6vuZrvJ/fmh5q',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'ell9505',
#     '_score': 1.0,
#     '_source': {'userid': 'ell9505',
#      'password': '$2a$11$J21OFd3Lh4V6J2uA92kMe.HNN97YnzX7j047a.InpCdqlIU6eIrea',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-geirarne',
#     '_score': 1.0,
#     '_source': {'userid': 't-geirarne',
#      'password': '$2a$11$ciZHUIL/ySrB1CLe8Z2QNuEHF2VbwXa8B6LW.aYaSsvyJxVLXS8rW',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'gro5550',
#     '_score': 1.0,
#     '_source': {'userid': 'gro5550',
#      'password': '$2a$11$tacXqm1dMqWWuNOUfnsDwOx30nm2cM3Kd93ZSxE0xFhf3G.lmg/6a',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_WEB_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-hakon',
#     '_score': 1.0,
#     '_source': {'userid': 'e-hakon',
#      'password': '$2a$11$dlYZVAtMY3fRZfKCfuVvP.r.sDUBH8UF6LgN4rksf9z7BR833x1ei',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-nl-prof6',
#     '_score': 1.0,
#     '_source': {'userid': 'e-nl-prof6',
#      'password': '$2a$11$nRzzhq47FiGG0gmX2vQMEej1teXRSmsrc8ivspSu9vZqEXvSg5IQS',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-test-4',
#     '_score': 1.0,
#     '_source': {'userid': 'i-test-4',
#      'password': '$2a$11$u3SfA6OwwUfo7.v0.KD.mOTcOWG5ckA/vvo2cpcy1f3g54oKyza3W',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-nl-prof5',
#     '_score': 1.0,
#     '_source': {'userid': 'e-nl-prof5',
#      'password': '$2a$11$g720aNb/gZIS9CWu.mSmXOCyOAaruJx1cSUXkjmMWnjUg8Wq7dzFO',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'a-kba21',
#     '_score': 1.0,
#     '_source': {'userid': 'a-kba21',
#      'password': '$2a$11$mcj9O9mrVUxfZyQkyBt4o.WlM4N.OSUpPCa2vfHri66v5trJJT/ue',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-test-android',
#     '_score': 1.0,
#     '_source': {'userid': 'i-test-android',
#      'password': '$2a$11$u3SfA6OwwUfo7.v0.KD.mOTcOWG5ckA/vvo2cpcy1f3g54oKyza3W',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-anna',
#     '_score': 1.0,
#     '_source': {'userid': 't-anna',
#      'password': '$2a$11$VW28u2uNfKWsMfK4j4R77ucBNYSm05EQcW9J1pC.ajO3m2Cj.rlF2',
#      'country': 'en',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'test-clj',
#     '_score': 1.0,
#     '_source': {'userid': 'test-clj',
#      'password': '$2a$11$w.nzhKzZURGdVDHNh6dIH.huuUjIZVD4rQ9OCiUdvOb2bvnOxAsI.',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-akelei',
#     '_score': 1.0,
#     '_source': {'userid': 'r-akelei',
#      'password': '$2a$11$eisfpoBZyyYKsmbhgbo3leem1.ig.6nHP102kYZO5Ftp5WzI8hndm',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-kirill-dk',
#     '_score': 1.0,
#     '_source': {'userid': 'i-kirill-dk',
#      'password': '$2a$11$nsD7Ymtny35fxPmVLiF3LOzxxsTwmKMiqM4xBtiV4NdsLRTpwfQR6',
#      'country': 'dk',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-viooltje',
#     '_score': 1.0,
#     '_source': {'userid': 'r-viooltje',
#      'password': '$2a$11$ybRqoeESLa1gPlW3wUlBB.mrrYAnkofbjEgQgwXuUn2m7ONn3YV6C',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-nl-prof7',
#     '_score': 1.0,
#     '_source': {'userid': 'e-nl-prof7',
#      'password': '$2a$11$fj4yIJ5m6NXJw2C7vUQi8etjBUHr7AjCVeYi8F6lEiqZT.ICzzG2.',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'nor4277',
#     '_score': 1.0,
#     '_source': {'userid': 'nor4277',
#      'password': '$2a$11$.zGr7520Ztzfg2Nqf.v44uETe55TILcAVJQGvWvCon9DZeNb7T1wG',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-annel',
#     '_score': 1.0,
#     '_source': {'userid': 'i-annel',
#      'password': '$2a$11$0tpQMuJV0rp4Hb9n3JqXFeeCbCnMFeGRFeTeJJpuOQVvCwngMam2e',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-madeliefje',
#     '_score': 1.0,
#     '_source': {'userid': 'r-madeliefje',
#      'password': '$2a$11$XCqF.OwIF9fESZqRoxz0geWoMwyYYtbL0/9JTCn98rNSEuT2A37ne',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-lise',
#     '_score': 1.0,
#     '_source': {'userid': 'e-lise',
#      'password': '$2a$11$kQhie9v1vrlLK.p/llQy3emR4bX002O5yvvhOuWJw2vV2KMSDyH7G',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-kerstin-2',
#     '_score': 1.0,
#     '_source': {'userid': 'i-kerstin-2',
#      'password': '$2a$11$sVwvOAr24ni0wu1g8o02jOyVsWIQkzQK75Aw7CQXoF5uUig2PNryC',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-annegismervik',
#     '_score': 1.0,
#     '_source': {'userid': 't-annegismervik',
#      'password': '$2a$11$wrrYyxnZt/CKusfG9XxegO2EEsGScKYnjtxMXSWpFPn5ubY0KGSVe',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'test-web-back',
#     '_score': 1.0,
#     '_source': {'userid': 'test-web-back',
#      'password': '$2a$11$xSwLUGss068M1YXF6UGRx.xLc.y26D7EDRpI3yef/C5ohCz9xA1BO',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_WEB_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-roos',
#     '_score': 1.0,
#     '_source': {'userid': 'r-roos',
#      'password': '$2a$11$bxGGYGLV1154Xprpk/Z7hO/gTN.V/YAFxvztoORXfwSbKUnqqvbzi',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-silje',
#     '_score': 1.0,
#     '_source': {'userid': 'e-silje',
#      'password': '$2a$11$8.9gw12h6xRfiy92MWCOb.u99xasyEeujWYE6sIzke5UItmWHE64y',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-hyacint',
#     '_score': 1.0,
#     '_source': {'userid': 'r-hyacint',
#      'password': '$2a$11$kz.ugvsRkwFoa5gppcuDZO6Vx.fhTjKymvwr7eFwRVyzuyenbx3iW',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-tone',
#     '_score': 1.0,
#     '_source': {'userid': 'e-tone',
#      'password': '$2a$11$UAu7Ra94fAK30YfoI2ts0Ovl6HOAcmPl2jeZOVTS109q1X74OqIES',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-margrete',
#     '_score': 1.0,
#     '_source': {'userid': 'i-margrete',
#      'password': '$2a$11$gVLflR7LxA43yMbnp3plW.vHm5osVCwJkv0ceu86yWa3dsIOBtHuK',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-waterlelie',
#     '_score': 1.0,
#     '_source': {'userid': 'r-waterlelie',
#      'password': '$2a$11$GfnnoZTkhbctXAozML8OVuLBTv0keWNNK0mB9rS40etEOqIKCvVGa',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-iris',
#     '_score': 1.0,
#     '_source': {'userid': 'r-iris',
#      'password': '$2a$11$ois5o91plol56ZkEMDF11.zl8nYIiH6T02RsofPQLl16tIrBTUN6G',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-lotus',
#     '_score': 1.0,
#     '_source': {'userid': 'r-lotus',
#      'password': '$2a$11$5MMhx5moR83O3Fadto9tyu6CLWwSeXgWwTHOXk1rYsGcPEncO5Mda',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'a-user',
#     '_score': 1.0,
#     '_source': {'userid': 'a-user',
#      'password': '$2a$11$A9Tmyjdi4FW2DmVNAanqv.eWrFvQLAB/twJOdIly/surRDklWR6Ba',
#      'country': 'en',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-begonia',
#     '_score': 1.0,
#     '_source': {'userid': 'r-begonia',
#      'password': '$2a$11$FCu8ew4hpIDrWP1OL5D4zOmwt5/731xRI4jhL11h6ckW0.SkhIFFW',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'baseline',
#     '_score': 1.0,
#     '_source': {'userid': 'baseline',
#      'password': '$2a$11$guD6SYpkeZKTJa7AwZuy8u5fYUVdxHV6HJuKPd6cS0F3fyzcl1aES',
#      'country': 'en',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_SERVER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'user2',
#     '_score': 1.0,
#     '_source': {'userid': 'user2',
#      'password': '$2a...',
#      'country': 'en',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-margriet',
#     '_score': 1.0,
#     '_source': {'userid': 'r-margriet',
#      'password': '$2a$11$aAoBAG475PcMRHk1lQ3Nde2lP5Hi3crEPdv36Ur/VYxJqSDxyRaUi',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-kirill-nl',
#     '_score': 1.0,
#     '_source': {'userid': 'i-kirill-nl',
#      'password': '$2a$11$xj2FDS/b6Ah6xz1wzCpyjONU8AInUYRqVbPWRo2WhU.vVm3J/tPbK',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-gladiool',
#     '_score': 1.0,
#     '_source': {'userid': 'r-gladiool',
#      'password': '$2a$11$UjJC0JcDgaIXT5C6YDBK1uTDrv5TlteRNsGw9TbdE8p0fK6SMeyGC',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'a-kba2',
#     '_score': 1.0,
#     '_source': {'userid': 'a-kba2',
#      'password': '$2a$11$mcj9O9mrVUxfZyQkyBt4o.WlM4N.OSUpPCa2vfHri66v5trJJT/ue',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 't-else',
#     '_score': 1.0,
#     '_source': {'userid': 't-else',
#      'password': '$2a$11$i72ZpJG1y6aDaItQR0gnWuMeRap9mRswBwBLEXkngWeWCA6Vis75C',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-kba-ios',
#     '_score': 1.0,
#     '_source': {'userid': 'i-kba-ios',
#      'password': '$2a$11$sVwvOAr24ni0wu1g8o02jOyVsWIQkzQK75Aw7CQXoF5uUig2PNryC',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'test-app-back',
#     '_score': 1.0,
#     '_source': {'userid': 'test-app-back',
#      'password': '$2a$11$B2oM5p.abx9qbTy8F2bM/.hbm0zOjDMlfB9M.Ago/JDWY.h7OUMAS',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'test-app-activate',
#     '_score': 1.0,
#     '_source': {'userid': 'test-app-activate',
#      'password': '$2a$11$nCVsKyhcyLdzUJwI1Z.s6u3rec82xqSHs8LtMnY0hdd7oG/qwfblC',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-lisemarita',
#     '_score': 1.0,
#     '_source': {'userid': 'e-lisemarita',
#      'password': '$2a$11$1oqF2TlkO0YEUVFSrVJyl.W7Kt7p3xb.bgEi.NsZAVLBz5g2kT2TW',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-nl-prof1',
#     '_score': 1.0,
#     '_source': {'userid': 'e-nl-prof1',
#      'password': '$2a$11$XIngWvSkyAH7WP5nGfkwz.ucYvsJMDm/59P6Xh4Vb6dVi/yNtgvTK',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-nl-prof2',
#     '_score': 1.0,
#     '_source': {'userid': 'e-nl-prof2',
#      'password': '$2a$11$hYsuB/R8fAsSmZXQRntL4ewTV.jf/9EtyBT.vadKrVjfumflHknAO',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'r-chrysant',
#     '_score': 1.0,
#     '_source': {'userid': 'r-chrysant',
#      'password': '$2a$11$AXDS/rnY3L3bCMgOLEYa0.VJIn0U5cX3j357B2uvvH.P7KXlfJ1EG',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'len4342',
#     '_score': 1.0,
#     '_source': {'userid': 'len4342',
#      'password': '$2a$11$6i2.G0f1/IipJsCL5ZfhreywNpocgIK3UDN6Lrc/RnE1VpXVrCrn.',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-elsenorun',
#     '_score': 1.0,
#     '_source': {'userid': 'i-elsenorun',
#      'password': '$2a$11$8k.3Fyys2sPKHPc/AHOlROvOPi2zyjNw8HwF0/1RfdOKDaZV5bisa',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'stuarttest',
#     '_score': 1.0,
#     '_source': {'userid': 'stuarttest',
#      'password': 'test',
#      'country': 'en',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'e-nl-prof3',
#     '_score': 1.0,
#     '_source': {'userid': 'e-nl-prof3',
#      'password': '$2a$11$nlURwvx2q2TBtuixQx8I4ul8X7ouPwr6mkUXOYosjqnT/rvaETc.m',
#      'country': 'nl',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'knu7641',
#     '_score': 1.0,
#     '_source': {'userid': 'knu7641',
#      'password': '$2a$11$uB9lCmnSNLdCsnGl0hhm6uRe5Cgc9TzTohH2zXA6ZBS2uA25tT3HW',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'i-test-kirill',
#     '_score': 1.0,
#     '_source': {'userid': 'i-test-kirill',
#      'password': '$2a$11$u3SfA6OwwUfo7.v0.KD.mOTcOWG5ckA/vvo2cpcy1f3g54oKyza3W',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}},
#    {'_index': 'account',
#     '_id': 'trx3',
#     '_score': 1.0,
#     '_source': {'userid': 'trx3',
#      'password': '$2a$11$mcj9O9mrVUxfZyQkyBt4o.WlM4N.OSUpPCa2vfHri66v5trJJT/ue',
#      'country': 'no',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_USER'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}}]}}

# %%
es.indices.get_mapping(index="account").body
# Out:
# /home/stuartgo/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   >>> conn = connection_from_url('http://google.com/')
# {'account': {'mappings': {'properties': {'clinician': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'country': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'isaccountnonexpired': {'type': 'boolean'},
#     'isaccountnonlocked': {'type': 'boolean'},
#     'iscredentialsnonexpired': {'type': 'boolean'},
#     'isenabled': {'type': 'boolean'},
#     'password': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'rights': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#     'userid': {'type': 'text',
#      'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}}}}}}

# %%
res = es.index(index='account', id="stuartgo", 
            document={
                'userid': 'stuartgo',
                'password': '$2b$12$phrVybcm8uyeTl9D/cdYoeZxiOHsjddjitMoYWv8lMVu9bMuY1L2a',
                'country': 'nl',
                'clinician': 'NTNU',
                'rights': 'ROLE_USER',
                'isaccountnonexpired': True,
                'isaccountnonlocked': True,
                'iscredentialsnonexpired': True,
                'isenabled': True}
)

print(es.indices.refresh(index='account'))
res
# Out:
# {'_shards': {'total': 10, 'successful': 5, 'failed': 0}}
# /home/stuartgo/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   >>> conn = connection_from_url('http://google.com/')
# /home/stuartgo/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   >>> conn = connection_from_url('http://google.com/')
# ObjectApiResponse({'_index': 'account', '_id': 'stuartgo', '_version': 22, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 37, '_primary_term': 3})

# %%
es.options(ignore_status=[400,404]).indices.delete(index='account')
# Out:
# /home/stuartgo/new_selfback/.venv/lib/python3.8/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ObjectApiResponse({'acknowledged': True})

# %% [markdown]
# ## Old Elasticsearch

# %%
from elasticsearch5 import Elasticsearch




es = Elasticsearch("http://localhost:9200")
es.indices.get_alias(index="*")
# Out:
# {'interaction': {'aliases': {}},
#  'app_settings': {'aliases': {}},
#  'data_description': {'aliases': {}},
#  'daily_goals': {'aliases': {}},
#  'notifications': {'aliases': {}},
#  'education_queue': {'aliases': {}},
#  'achievement': {'aliases': {}},
#  'account': {'aliases': {}},
#  'cases': {'aliases': {}},
#  'variables': {'aliases': {}},
#  'questionnaire': {'aliases': {}},
#  '.kibana': {'aliases': {}},
#  'feedback': {'aliases': {}},
#  'baseline': {'aliases': {}},
#  'app_interaction': {'aliases': {}},
#  'notification_settings': {'aliases': {}},
#  'education': {'aliases': {}},
#  'plan': {'aliases': {}},
#  'exercise': {'aliases': {}},
#  'activity': {'aliases': {}},
#  'follow_up': {'aliases': {}}}

# %%
language="en"
query={"query":{'match' : {"_type":"education_"+language}}}
query={"query":{'match_all' : {}}}
res = es.search(index="data_description", body=query,size=10000)
print(len(res["hits"]["hits"]))
res["hits"]["hits"]

# %%
res = es.search(index="plan", body={"query":{'match' : {"_type":"t-anne"}}},size=100)
res
# Out:
# {'took': 4,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'failed': 0},
#  'hits': {'total': 6,
#   'max_score': 1.0,
#   'hits': [{'_index': 'plan',
#     '_type': 't-anne',
#     '_id': 'AXLGsgcb3yIeDN3WNBBj',
#     '_score': 1.0,
#     '_source': {'created': 1592471455342,
#      'start': 1592431200000,
#      'end': 1593035999999,
#      'exercises_duration': 35,
#      'history': [{'date': 1592471455342,
#        'exercises': [{'exerciseid': 'ab_02_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'back_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_09',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'glut_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'core_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_08',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30}],
#        'educations': [{'educationid': 'Encouragement to SM_7',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Me time_1', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Problem solving_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Daily activity_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Action planning_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Pacing_3', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Goal setting_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Fear-avoidance_1',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 4800,
#         'recommended_min': 4300,
#         'recommended_max': 5300}},
#       {'date': 1592471467587,
#        'exercises': [{'exerciseid': 'ab_02_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'back_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_09',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'glut_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'core_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_08',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30}],
#        'educations': [{'educationid': 'Encouragement to SM_7',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Me time_1', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Problem solving_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Daily activity_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Action planning_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Pacing_3', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Goal setting_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Fear-avoidance_1',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 5300,
#         'recommended_min': 4800,
#         'recommended_max': 5800}},
#       {'date': 1593028799503,
#        'exercises': [{'exerciseid': 'ab_02_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'back_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_09',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'glut_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_02_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'core_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_08',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30}],
#        'educations': [{'educationid': 'Encouragement to SM_7',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Me time_1', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Problem solving_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Daily activity_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Action planning_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Pacing_3', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Goal setting_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Fear-avoidance_1',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 5300,
#         'recommended_min': 4800,
#         'recommended_max': 5800}}],
#      'plan': {'date': 1593028799503,
#       'exercises': [{'exerciseid': 'ab_02_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'back_01_01',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'flex_01_09',
#         'sets': 1,
#         'reps': 1,
#         'set_duration_s': 30},
#        {'exerciseid': 'glut_01_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'flex_02_01',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'core_01_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'flex_01_08',
#         'sets': 1,
#         'reps': 1,
#         'set_duration_s': 30}],
#       'educations': [{'educationid': 'Encouragement to SM_7',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Me time_1', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Problem solving_4',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Daily activity_5',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Action planning_1',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Pacing_3', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Goal setting_3',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Fear-avoidance_1',
#         'is_quiz': False,
#         'is_correct': False}],
#       'activity': {'goal': 5300,
#        'recommended_min': 4800,
#        'recommended_max': 5800}},
#      'done': {'date': 1593076255342,
#       'exercises': [{'exerciseid': 'flex_01_09',
#         'sets': 0,
#         'reps': 3,
#         'set_duration_s': 0},
#        {'exerciseid': 'back_01_01',
#         'sets': 0,
#         'reps': 90,
#         'set_duration_s': 0},
#        {'exerciseid': 'flex_01_03',
#         'sets': 0,
#         'reps': 60,
#         'set_duration_s': 0},
#        {'exerciseid': 'core_01_02',
#         'sets': 0,
#         'reps': 60,
#         'set_duration_s': 0},
#        {'exerciseid': 'flex_01_08', 'sets': 0, 'reps': 2, 'set_duration_s': 0},
#        {'exerciseid': 'ab_02_02', 'sets': 0, 'reps': 59, 'set_duration_s': 0},
#        {'exerciseid': 'glut_01_02',
#         'sets': 0,
#         'reps': 60,
#         'set_duration_s': 0}],
#       'educations': [{'educationid': 'Encouragement to SM_7',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Daily activity_5',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Action planning_1',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Pacing_3', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Goal setting_3',
#         'is_quiz': False,
#         'is_correct': False}],
#       'activity': {'goal': 177,
#        'recommended_min': 3000,
#        'recommended_max': 3000}}}},
#    {'_index': 'plan',
#     '_type': 't-anne',
#     '_id': 'AXLrWHTb3yIeDN3WNBgB',
#     '_score': 1.0,
#     '_source': {'created': 1593086342225,
#      'start': 1593036000000,
#      'end': 1593640799999,
#      'exercises_duration': 35,
#      'history': [{'date': 1593086342225,
#        'exercises': [{'exerciseid': 'pain_03_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_04_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_04_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Me time_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Encouragement to SM_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Problem solving_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Pacing_2', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Distraction_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Goal setting_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_4', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Work_2', 'is_quiz': False, 'is_correct': False}],
#        'activity': {'goal': 4200,
#         'recommended_min': 3800,
#         'recommended_max': 4600}},
#       {'date': 1593086359039,
#        'exercises': [{'exerciseid': 'pain_03_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_04_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_04_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Me time_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Encouragement to SM_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Problem solving_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Pacing_2', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Distraction_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Goal setting_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_4', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Work_2', 'is_quiz': False, 'is_correct': False}],
#        'activity': {'goal': 4600,
#         'recommended_min': 4100,
#         'recommended_max': 5100}},
#       {'date': 1593500498588,
#        'exercises': [{'exerciseid': 'pain_03_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_05_05',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_04_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Me time_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Encouragement to SM_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Problem solving_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Pacing_2', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Distraction_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Goal setting_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_4', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Work_2', 'is_quiz': False, 'is_correct': False}],
#        'activity': {'goal': 4600,
#         'recommended_min': 4100,
#         'recommended_max': 5100}}],
#      'plan': {'date': 1593500498588,
#       'exercises': [{'exerciseid': 'pain_03_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'pain_03_01',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'pain_03_03',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'pain_05_05',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'pain_04_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'pain_01_01',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'pain_01_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1}],
#       'educations': [{'educationid': 'Me time_1',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Encouragement to SM_1',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Problem solving_4',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Pacing_2', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Distraction_1', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Goal setting_2',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Relaxation_4', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Work_2', 'is_quiz': False, 'is_correct': False}],
#       'activity': {'goal': 4600,
#        'recommended_min': 4100,
#        'recommended_max': 5100}},
#      'done': {'date': 1593691142225,
#       'exercises': [{'exerciseid': 'pain_04_01',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'pain_01_02',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'pain_01_01',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'pain_05_05',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'pain_04_02',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'pain_03_02',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'pain_03_01',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'pain_03_03',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0}],
#       'educations': [{'educationid': 'Encouragement to SM_1',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Problem solving_4',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Distraction_1', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Goal setting_2',
#         'is_quiz': False,
#         'is_correct': False}],
#       'activity': {'goal': 2,
#        'recommended_min': 3000,
#        'recommended_max': 3000}}}},
#    {'_index': 'plan',
#     '_type': 't-anne',
#     '_id': 'AXMOHnyJ3yIeDN3WNCb9',
#     '_score': 1.0,
#     '_source': {'created': 1593669745734,
#      'start': 1593640800000,
#      'end': 1594245599999,
#      'exercises_duration': 20,
#      'history': [{'date': 1593669745734,
#        'exercises': [{'exerciseid': 'ab_02_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'back_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_09',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'glut_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Me time_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Problem solving_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Work_2', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Relaxation_4', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Start exercise_10',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Reassurance_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Stay active_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Family and friends_1',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 3800,
#         'recommended_min': 3400,
#         'recommended_max': 4200}},
#       {'date': 1593669754008,
#        'exercises': [{'exerciseid': 'ab_02_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'back_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_09',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'glut_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Me time_1',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Problem solving_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Work_2', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Relaxation_4', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Start exercise_10',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Reassurance_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Stay active_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Family and friends_1',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 4200,
#         'recommended_min': 3800,
#         'recommended_max': 4600}}],
#      'plan': {'date': 1593669754008,
#       'exercises': [{'exerciseid': 'ab_02_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'back_01_01',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'flex_01_09',
#         'sets': 1,
#         'reps': 1,
#         'set_duration_s': 30},
#        {'exerciseid': 'glut_01_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1}],
#       'educations': [{'educationid': 'Me time_1',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Problem solving_2',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Work_2', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Relaxation_4', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Start exercise_10',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Reassurance_4', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Stay active_5', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Family and friends_1',
#         'is_quiz': False,
#         'is_correct': False}],
#       'activity': {'goal': 4200,
#        'recommended_min': 3800,
#        'recommended_max': 4600}},
#      'done': {'date': 1594274545734,
#       'exercises': [],
#       'educations': [{'educationid': 'Me time_1',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Problem solving_2',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Relaxation_4', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Start exercise_10',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Reassurance_4', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Stay active_5',
#         'is_quiz': False,
#         'is_correct': False}],
#       'activity': {'goal': 6125,
#        'recommended_min': 5200,
#        'recommended_max': 7000}}}},
#    {'_index': 'plan',
#     '_type': 't-anne',
#     '_id': 'AXKeSJ293yIeDN3WNAWk',
#     '_score': 1.0,
#     '_source': {'created': 1591793458575,
#      'start': 1591740000000,
#      'end': 1592344799999,
#      'exercises_duration': 15,
#      'history': [{'date': 1591793458575,
#        'exercises': [{'exerciseid': 'pain_03_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Encouragement to SM_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Goal setting_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Me time_2', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Problem solving_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Action planning_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Reassurance_9',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_5', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Distraction_1',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 6500,
#         'recommended_min': 5500,
#         'recommended_max': 7500}},
#       {'date': 1591793462888,
#        'exercises': [{'exerciseid': 'pain_03_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Encouragement to SM_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Goal setting_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Me time_2', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Problem solving_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Action planning_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Reassurance_9',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_5', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Distraction_1',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 6500,
#         'recommended_min': 5500,
#         'recommended_max': 7500}},
#       {'date': 1592157947440,
#        'exercises': [{'exerciseid': 'pain_05_05',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'pain_03_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Encouragement to SM_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Goal setting_5',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Me time_2', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Problem solving_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Action planning_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Reassurance_9',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_5', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Distraction_1',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 6500,
#         'recommended_min': 5500,
#         'recommended_max': 7500}}],
#      'plan': {'date': 1592157947440,
#       'exercises': [{'exerciseid': 'pain_05_05',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'pain_03_01',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'pain_03_03',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1}],
#       'educations': [{'educationid': 'Encouragement to SM_5',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Goal setting_5',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Me time_2', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Problem solving_4',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Action planning_3',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Reassurance_9', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Relaxation_5', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Distraction_1',
#         'is_quiz': False,
#         'is_correct': False}],
#       'activity': {'goal': 6500,
#        'recommended_min': 5500,
#        'recommended_max': 7500}},
#      'done': {'date': 1592398258575,
#       'exercises': [{'exerciseid': 'pain_03_03',
#         'sets': 0,
#         'reps': 60,
#         'set_duration_s': 0},
#        {'exerciseid': 'pain_03_01',
#         'sets': 0,
#         'reps': 60,
#         'set_duration_s': 0},
#        {'exerciseid': 'pain_03_02',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'pain_05_05',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0}],
#       'educations': [{'educationid': 'Encouragement to SM_5',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Goal setting_5',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Me time_2', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Action planning_3',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Reassurance_9', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Relaxation_5', 'is_quiz': False, 'is_correct': False}],
#       'activity': {'goal': 8,
#        'recommended_min': 3000,
#        'recommended_max': 3000}}}},
#    {'_index': 'plan',
#     '_type': 't-anne',
#     '_id': 'AXM3kv5s3yIeDN3WNDFi',
#     '_score': 1.0,
#     '_source': {'created': 1594365246967,
#      'start': 1594332000000,
#      'end': 1594936799999,
#      'exercises_duration': 30,
#      'history': [{'date': 1594365246967,
#        'exercises': [{'exerciseid': 'core_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'ab_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'backneck_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'glut_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_09',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'flex_01_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Pacing_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Start exercise_9',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Encouragement to SM_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_3', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Stay active_7',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Action planning_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Goal setting_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Fear-avoidance_4',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 5200,
#         'recommended_min': 4700,
#         'recommended_max': 5700}},
#       {'date': 1594365253264,
#        'exercises': [{'exerciseid': 'core_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'ab_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'backneck_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'glut_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_09',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'flex_01_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Pacing_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Start exercise_9',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Encouragement to SM_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_3', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Stay active_7',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Action planning_2',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Goal setting_4',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Fear-avoidance_4',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 5700,
#         'recommended_min': 5100,
#         'recommended_max': 6300}}],
#      'plan': {'date': 1594365253264,
#       'exercises': [{'exerciseid': 'core_01_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'ab_01_02', 'sets': 3, 'reps': 10, 'set_duration_s': -1},
#        {'exerciseid': 'backneck_01_01',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'glut_01_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'flex_01_09',
#         'sets': 1,
#         'reps': 1,
#         'set_duration_s': 30},
#        {'exerciseid': 'flex_01_03',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1}],
#       'educations': [{'educationid': 'Pacing_2',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Start exercise_9',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Encouragement to SM_2',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Relaxation_3', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Stay active_7', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Action planning_2',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Goal setting_4',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Fear-avoidance_4',
#         'is_quiz': False,
#         'is_correct': False}],
#       'activity': {'goal': 5700,
#        'recommended_min': 5100,
#        'recommended_max': 6300}},
#      'done': {'date': 1594970046967,
#       'exercises': [{'exerciseid': 'ab_01_02',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0}],
#       'educations': [{'educationid': 'Pacing_2',
#         'is_quiz': False,
#         'is_correct': False}],
#       'activity': {'goal': 0,
#        'recommended_min': 3000,
#        'recommended_max': 3000}}}},
#    {'_index': 'plan',
#     '_type': 't-anne',
#     '_id': 'AXJ0Rx0P3yIeDN3WM-pU',
#     '_score': 1.0,
#     '_source': {'created': 1591088717060,
#      'start': 1591048800000,
#      'end': 1591653599999,
#      'exercises_duration': 50,
#      'history': [{'date': 1591088717060,
#        'exercises': [{'exerciseid': 'core_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_09',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'backneck_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'glut_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'ab_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_08',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'glut_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'neck_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Family and friends_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Problem solving_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Changing negative thoughts_9',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Attitude_5', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Encouragement to SM_7',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Mind-body connection_6',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Stay active_10',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_5',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 3000,
#         'recommended_min': 3000,
#         'recommended_max': 10000}},
#       {'date': 1591088724003,
#        'exercises': [{'exerciseid': 'core_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_09',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'backneck_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'glut_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'ab_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_08',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'glut_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'neck_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Family and friends_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Problem solving_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Changing negative thoughts_9',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Attitude_5', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Encouragement to SM_7',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Mind-body connection_6',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Stay active_10',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_5',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 10000,
#         'recommended_min': 8000,
#         'recommended_max': 10000}},
#       {'date': 1591169768090,
#        'exercises': [{'exerciseid': 'core_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_09',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'backneck_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'glut_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_03',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'ab_02_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_08',
#          'sets': 1,
#          'reps': 1,
#          'set_duration_s': 30},
#         {'exerciseid': 'glut_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'neck_01_01',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1},
#         {'exerciseid': 'flex_01_02',
#          'sets': 3,
#          'reps': 10,
#          'set_duration_s': -1}],
#        'educations': [{'educationid': 'Family and friends_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Problem solving_3',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Changing negative thoughts_9',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Attitude_5', 'is_quiz': False, 'is_correct': False},
#         {'educationid': 'Encouragement to SM_7',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Mind-body connection_6',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Stay active_10',
#          'is_quiz': False,
#          'is_correct': False},
#         {'educationid': 'Relaxation_5',
#          'is_quiz': False,
#          'is_correct': False}],
#        'activity': {'goal': 10000,
#         'recommended_min': 8000,
#         'recommended_max': 10000}}],
#      'plan': {'date': 1591169768090,
#       'exercises': [{'exerciseid': 'core_01_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'flex_01_09',
#         'sets': 1,
#         'reps': 1,
#         'set_duration_s': 30},
#        {'exerciseid': 'backneck_01_01',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'glut_01_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'flex_01_03',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'ab_02_01', 'sets': 3, 'reps': 10, 'set_duration_s': -1},
#        {'exerciseid': 'flex_01_08',
#         'sets': 1,
#         'reps': 1,
#         'set_duration_s': 30},
#        {'exerciseid': 'glut_01_01',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'neck_01_01',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1},
#        {'exerciseid': 'flex_01_02',
#         'sets': 3,
#         'reps': 10,
#         'set_duration_s': -1}],
#       'educations': [{'educationid': 'Family and friends_3',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Problem solving_3',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Changing negative thoughts_9',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Attitude_5', 'is_quiz': False, 'is_correct': False},
#        {'educationid': 'Encouragement to SM_7',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Mind-body connection_6',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Stay active_10',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Relaxation_5', 'is_quiz': False, 'is_correct': False}],
#       'activity': {'goal': 10000,
#        'recommended_min': 8000,
#        'recommended_max': 10000}},
#      'done': {'date': 1591693517060,
#       'exercises': [{'exerciseid': 'neck_01_01',
#         'sets': 0,
#         'reps': 60,
#         'set_duration_s': 0},
#        {'exerciseid': 'core_01_02',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'flex_01_03',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'ab_02_01', 'sets': 0, 'reps': 30, 'set_duration_s': 0},
#        {'exerciseid': 'flex_01_08', 'sets': 0, 'reps': 1, 'set_duration_s': 0},
#        {'exerciseid': 'flex_01_09', 'sets': 0, 'reps': 1, 'set_duration_s': 0},
#        {'exerciseid': 'glut_01_01',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'backneck_01_01',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'glut_01_02',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0},
#        {'exerciseid': 'flex_01_02',
#         'sets': 0,
#         'reps': 30,
#         'set_duration_s': 0}],
#       'educations': [{'educationid': 'Family and friends_3',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Problem solving_3',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Changing negative thoughts_9',
#         'is_quiz': False,
#         'is_correct': False},
#        {'educationid': 'Attitude_5', 'is_quiz': False, 'is_correct': False}],
#       'activity': {'goal': 421,
#        'recommended_min': 3000,
#        'recommended_max': 3000}}}}]}}

# %%
res = es.search(index="account", body={"query":{'match' : {"userid":"admin"}}},size=100)
res
# Out:
# {'took': 262,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'failed': 0},
#  'hits': {'total': 1,
#   'max_score': 3.7738225,
#   'hits': [{'_index': 'account',
#     '_type': 'patient_account',
#     '_id': 'admin',
#     '_score': 3.7738225,
#     '_source': {'userid': 'admin',
#      'password': '$2a$11$3BZVzXVnSghEyfTvHWIoCuS5rHp3ehyBexOz54O6FmejnTtLg9Ct2',
#      'country': 'en',
#      'clinician': 'NTNU',
#      'rights': ['ROLE_ADMIN', 'ACTUATOR'],
#      'isaccountnonexpired': True,
#      'isaccountnonlocked': True,
#      'iscredentialsnonexpired': True,
#      'isenabled': True}}]}}

# %%
response=requests.post(
    "https://back-up.idi.ntnu.no/oauth/token",
    data={'grant_type': 'password',"username":"stuartFinal2","password":"cWbWaN6qgAVjhxdqqx5Ht"},
    verify=False,
    allow_redirects=False,
    auth=("my-trusted-client","secret")
)
token=response.json()["access_token"]
response.json()
# Out:
# /home/stuartgo/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'back-up.idi.ntnu.no'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'access_token': 'tRqdbfVmYqw27xk1pFwoLMv1nHU',
#  'token_type': 'bearer',
#  'scope': 'read write trust'}

# %%
response=requests.get("https://back-up.idi.ntnu.no/patient/baseline",verify=False,
                      headers={"Authorization": f"Bearer {token}"}
                      )
response.json()

# %%
response=requests.post("https://back-up.idi.ntnu.no/patient/plan/next",verify=False,
                      headers={"Authorization": f"Bearer {token}"},
                      json={
                            "exercises_duration": 35,
                            }
                      )
print(response)
response.json()
# Out:
# /home/stuartgo/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'back-up.idi.ntnu.no'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# <Response [200]>
# {'created': 1687337957813,
#  'start': 1687305600000,
#  'end': 1687910399999,
#  'exercises_duration': 35,
#  'history': [{'date': 1687337957813,
#    'exercises': [{'exerciseid': 'core_01_02',
#      'sets': 3,
#      'reps': 10,
#      'set_duration_s': -1},
#     {'exerciseid': 'flex_01_09', 'sets': 1, 'reps': 1, 'set_duration_s': 30},
#     {'exerciseid': 'backneck_01_01',
#      'sets': 3,
#      'reps': 10,
#      'set_duration_s': -1},
#     {'exerciseid': 'glut_01_02', 'sets': 3, 'reps': 10, 'set_duration_s': -1},
#     {'exerciseid': 'flex_01_03', 'sets': 3, 'reps': 10, 'set_duration_s': -1},
#     {'exerciseid': 'ab_01_02', 'sets': 3, 'reps': 10, 'set_duration_s': -1},
#     {'exerciseid': 'flex_01_08', 'sets': 1, 'reps': 1, 'set_duration_s': 30}],
#    'educations': [{'educationid': 'Family and friends_3',
#      'is_quiz': False,
#      'is_correct': False},
#     {'educationid': 'Problem solving_3',
#      'is_quiz': False,
#      'is_correct': False},
#     {'educationid': 'Stay active_10', 'is_quiz': False, 'is_correct': False},
#     {'educationid': 'Changing negative thoughts_9',
#      'is_quiz': False,
#      'is_correct': False},
#     {'educationid': 'Attitude_5', 'is_quiz': False, 'is_correct': False},
#     {'educationid': 'Encouragement to SM_7',
#      'is_quiz': False,
#      'is_correct': False},
#     {'educationid': 'Mind-body connection_6',
#      'is_quiz': False,
#      'is_correct': False},
#     {'educationid': 'Relaxation_5', 'is_quiz': False, 'is_correct': False}],
#    'activity': {'goal': 3000,
#     'recommended_min': 3000,
#     'recommended_max': 10000}}],
#  'plan': {'date': 1687337957813,
#   'exercises': [{'exerciseid': 'core_01_02',
#     'sets': 3,
#     'reps': 10,
#     'set_duration_s': -1},
#    {'exerciseid': 'flex_01_09', 'sets': 1, 'reps': 1, 'set_duration_s': 30},
#    {'exerciseid': 'backneck_01_01',
#     'sets': 3,
#     'reps': 10,
#     'set_duration_s': -1},
#    {'exerciseid': 'glut_01_02', 'sets': 3, 'reps': 10, 'set_duration_s': -1},
#    {'exerciseid': 'flex_01_03', 'sets': 3, 'reps': 10, 'set_duration_s': -1},
#    {'exerciseid': 'ab_01_02', 'sets': 3, 'reps': 10, 'set_duration_s': -1},
#    {'exerciseid': 'flex_01_08', 'sets': 1, 'reps': 1, 'set_duration_s': 30}],
#   'educations': [{'educationid': 'Family and friends_3',
#     'is_quiz': False,
#     'is_correct': False},
#    {'educationid': 'Problem solving_3', 'is_quiz': False, 'is_correct': False},
#    {'educationid': 'Stay active_10', 'is_quiz': False, 'is_correct': False},
#    {'educationid': 'Changing negative thoughts_9',
#     'is_quiz': False,
#     'is_correct': False},
#    {'educationid': 'Attitude_5', 'is_quiz': False, 'is_correct': False},
#    {'educationid': 'Encouragement to SM_7',
#     'is_quiz': False,
#     'is_correct': False},
#    {'educationid': 'Mind-body connection_6',
#     'is_quiz': False,
#     'is_correct': False},
#    {'educationid': 'Relaxation_5', 'is_quiz': False, 'is_correct': False}],
#   'activity': {'goal': 3000,
#    'recommended_min': 3000,
#    'recommended_max': 10000}},
#  'done': {'date': 1687942757813,
#   'exercises': [],
#   'educations': [],
#   'activity': {'goal': 0, 'recommended_min': 3000, 'recommended_max': 3000}}}

# %%
response=requests.post("http://localhost:30000/token",data={"username":"stuartgo","password":"secret"}
)
token=response.json()["access_token"]
response.json()
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJzdHVhcnRnbyIsImV4cCI6MTY4NzM0MDQ1NH0.luv0IBuCZB8b4Z0H8SSHTyvrtm_eajsJvPEPmgkJ77w',
#  'token_type': 'bearer'}

# %%
response=requests.post("https://localhost:30000/patient/plan/next",verify=False,
                      headers={"Authorization": f"Bearer {token}"},
                      json={
                            "exercises_duration": 35,
                            }
                      )
print(response)
response.json()
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File /usr/lib/python3.9/ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File /usr/lib/python3.9/ssl.py:1041, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1040             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041         self.do_handshake()
#    1042 except (OSError, ValueError):
#
# File /usr/lib/python3.9/ssl.py:1310, in SSLSocket.do_handshake(self, block)
#    1309         self.settimeout(None)
# -> 1310     self._sslobj.do_handshake()
#    1311 finally:
#
# SSLError: [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='localhost', port=30000): Max retries exceeded with url: /patient/plan/next (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 response=requests.post("https://localhost:30000/patient/plan/next",verify=False,
#       2                       headers={"Authorization": f"Bearer {token}"},
#       3                       json={
#       4                             "exercises_duration": 35,
#       5                             }
#       6                       )
#       7 print(response)
#       8 response.json()
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/adapters.py:517, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     513         raise ProxyError(e, request=request)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
# --> 517         raise SSLError(e, request=request)
#     519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='localhost', port=30000): Max retries exceeded with url: /patient/plan/next (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)')))

# %%
response=requests.get("http://localhost:30000/data/patient/baseline",headers={"Authorization": f"Bearer {token}"}
)
response.json()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:415, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414     else:
# --> 415         conn.request(method, url, **httplib_request_kw)
#     417 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     418 # legitimately able to close the connection after sending a valid response.
#     419 # With this behaviour, the received response is still readable.
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File /usr/lib/python3.9/http/client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.9/http/client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.9/http/client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.9/http/client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File /usr/lib/python3.9/http/client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f34d6b8e070>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=30000): Max retries exceeded with url: /data/patient/baseline (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f34d6b8e070>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 response=requests.get("http://localhost:30000/data/patient/baseline",headers={"Authorization": f"Bearer {token}"}
#       2 )
#       3 response.json()
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/new_selfback/.venv/lib/python3.9/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=30000): Max retries exceeded with url: /data/patient/baseline (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f34d6b8e070>: Failed to establish a new connection: [Errno 111] Connection refused'))
