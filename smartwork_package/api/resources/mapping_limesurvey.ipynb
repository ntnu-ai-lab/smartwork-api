# %%
import json

# %%
with open('LS_response.json', 'r') as file:
    data = json.load(file)
print(data)
# Out:
# {'_index': 'patients', '_type': '_doc', '_id': 'e09249e1-578e-448b-8e4c-1717c967d64f', '_version': 1, '_score': 1, '_source': {'_class': 'no.ntnu.smartwork.elastic_interface.model.Patient', 'id': 'e09249e1-578e-448b-8e4c-1717c967d64f', 'patientId': 'ani425', 'questionnaireType': 'baseline1', 'dateCreated': '2024-09-23T15:51:57.376+02:00', 'dateUpdated': '2024-09-23T15:51:57.496+02:00', 'patientDetails': {'AdaptWork1': None, 'AdaptWork2': None, 'AdaptWork3': None, 'Age': None, 'BIPQConcern_answer': '10', 'BIPQControl_answer': '10', 'BIPQEmotion_answer': '10', 'BIPQLife_answer': '9', 'BIPQPainContinuation_answer': '10', 'BIPQSelfmanagement_answer': '10', 'BIPQSymptoms_answer': '10', 'BIPQUnderstanding_answer': '10', 'BMI': None, 'BTPHQ2Item': '6', 'BTPSEQ2Item': '12', 'Comorbidities': None, 'ComorbiditiesPre_SQ001': None, 'ComorbiditiesPre_SQ002': None, 'ComorbiditiesPre_SQ003': None, 'ComorbiditiesPre_SQ004': None, 'ComorbiditiesPre_SQ005': None, 'ComorbiditiesPre_SQ006': None, 'Comor
# ...

# %%
#required fields
required_fields_cbr=[
    "Dem_age",
    "Dem_"
]

# %%
Dem_age
Dem_gender
Dem_height
Dem_weight
Dem_bmi
FamilyFamily
EducationEducation
Employmentment
Work_characteristicsWork_characteristics
BT_pain_averageBT_pain_average
Pain_worstPain_worst
Pain_currentPain_current
Pain_sitesPain_sites
BT_waiBT_wai
T_cpg_functionT_cpg_function
ComorbiditiesComorbidities
EQ5D_mobilitylity
EQ5D_selfcareEQ5D_selfcare
EQ5D_activityEQ5D_activity
EQ5D_painEQ5D_pain
EQ5D_anxietyEQ5D_anxiety
EQ5DEQ5D
Sleep_difficultyiculty
Sleep_wakeupSleep_wakeup
Sleep_endSleep_end
Sleep_daySleep_day
T_sleepT_sleep
T_tampa_fearT_tampa_fear
BIPQ_lifeBIPQ_life
BIPQ_pain_continuationBIPQ_pain_continuation
BIPQ_controlBIPQ_control
BIPQ_selfmanagementBIPQ_selfmanagement
BIPQ_symptoms
BIPQ_concernBIPQ_concern
BIPQ_understandingBIPQ_understanding
BIPQ_emotionBIPQ_emotion
Pain_self_efficacyPain_self_efficacy
BT_PSEQ_2item
PSSPSS
BT_PSSBT_PSS
PHQ
BT_PHQ_2itemBT_PHQ_2item
T_barriersT_barriers
F_GPE

# %%
data["_source"]
# Out:
# {'_class': 'no.ntnu.smartwork.elastic_interface.model.Patient',
#  'id': 'e09249e1-578e-448b-8e4c-1717c967d64f',
#  'patientId': 'ani425',
#  'questionnaireType': 'baseline1',
#  'dateCreated': '2024-09-23T15:51:57.376+02:00',
#  'dateUpdated': '2024-09-23T15:51:57.496+02:00',
#  'patientDetails': {'AdaptWork1': None,
#   'AdaptWork2': None,
#   'AdaptWork3': None,
#   'Age': None,
#   'BIPQConcern_answer': '10',
#   'BIPQControl_answer': '10',
#   'BIPQEmotion_answer': '10',
#   'BIPQLife_answer': '9',
#   'BIPQPainContinuation_answer': '10',
#   'BIPQSelfmanagement_answer': '10',
#   'BIPQSymptoms_answer': '10',
#   'BIPQUnderstanding_answer': '10',
#   'BMI': None,
#   'BTPHQ2Item': '6',
#   'BTPSEQ2Item': '12',
#   'Comorbidities': None,
#   'ComorbiditiesPre_SQ001': None,
#   'ComorbiditiesPre_SQ002': None,
#   'ComorbiditiesPre_SQ003': None,
#   'ComorbiditiesPre_SQ004': None,
#   'ComorbiditiesPre_SQ005': None,
#   'ComorbiditiesPre_SQ006': None,
# ...
