# %%
import requests

# %%
response=requests.post("http://localhost:30000/token",data={"username":"user","password":"secret"}
)
print(response)
token=response.json()["access_token"]
response.json()
# Out:
# <Response [200]>
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ1c2VyIiwiZXhwIjoxNjg4OTgxMzk1fQ.b7dUe-FwN9KZ3K2bAiNNBFwPnHO2fohetJYvKWat3Mw',
#  'token_type': 'bearer'}

# %%
response=requests.post("http://localhost:30000/patient/activity",
                       headers={"Authorization": f"Bearer {token}"},
                       json={
                           "activities":[{"start":100,"end":200,"type":"potato","steps":200}]
                       }
)
response.json()
# Out:
# {'pot': 'ato'}

# %%
response=requests.post("http://localhost:30000/patient/plan/next",
                       headers={"Authorization": f"Bearer {token}"},
                       json={
                           "questionnaire":{"Dem_age":42},
                            "exercise_duration":15
                       }
)
response.json()
# Out:
# [{'lastusage': 0,
#   'group': 13,
#   'priority': 2,
#   'used': False,
#   'usednumber': 0,
#   'expiredate': 1595019975527.0,
#   'id': 'Changing negative thoughts_7',
#   'thisweek': False,
#   'lastquiz': False},
#  {'usedNumber': 0,
#   'priority': 1,
#   'thisweek': False,
#   'used': False,
#   'id': 'Cause of LBP_1',
#   'lastUsage': 0,
#   'expiredate': 1688731778,
#   'excluded': False,
#   'lastQuiz': False,
#   'group': 0,
#   'avoid': False},
#  {'id': 'Guideline LBP_1',
#   'lastUsage': 0,
#   'excluded': False,
#   'usedNumber': 0,
#   'group': 1,
#   'expiredate': 1688731778,
#   'avoid': False,
#   'lastQuiz': False,
#   'thisweek': False,
#   'priority': 1,
#   'used': False},
#  {'priority': 1,
#   'excluded': False,
#   'used': False,
#   'lastUsage': 0,
#   'usedNumber': 0,
#   'id': 'Imaging_2',
#   'expiredate': 1688731778,
#   'lastQuiz': False,
#   'avoid': False,
#   'thisweek': False,
#   'group': 2},
#  {'excluded': False,
#   'lastQuiz': False,
#   'avoid': False,
#   'lastUsage': 0,
#   'used': False,
#   'group': 3,
#   'id': 'Pain rating_1',
#   'usedNumber': 0,
#   'priority': 1,
#   'thisweek': False,
#   'expiredate': 1688731778},
#  {'used': False,
#   'usedNumber': 0,
#   'excluded': False,
#   'lastQuiz': False,
#   'priority': 1,
#   'group': 4,
#   'avoid': False,
#   'expiredate': 1688731778,
#   'thisweek': False,
#   'id': 'Reassurance_4',
#   'lastUsage': 0},
#  {'usedNumber': 0,
#   'priority': 1,
#   'id': 'Stay active_1',
#   'used': False,
#   'avoid': False,
#   'lastUsage': 0,
#   'expiredate': 1688731778,
#   'thisweek': False,
#   'lastQuiz': False,
#   'group': 5,
#   'excluded': False},
#  {'excluded': False,
#   'avoid': False,
#   'id': 'Structure of back_2',
#   'lastQuiz': False,
#   'priority': 1,
#   'lastUsage': 0,
#   'thisweek': False,
#   'used': False,
#   'usedNumber': 0,
#   'expiredate': 1688731778,
#   'group': 7},
#  {'lastUsage': 0,
#   'thisweek': False,
#   'priority': 1,
#   'group': 8,
#   'lastQuiz': False,
#   'expiredate': 1688731778,
#   'avoid': False,
#   'excluded': False,
#   'used': False,
#   'usedNumber': 0,
#   'id': 'Mind-body connection_1'},
#  {'used': False,
#   'avoid': False,
#   'lastQuiz': False,
#   'excluded': False,
#   'expiredate': 1688731778,
#   'thisweek': False,
#   'priority': 1,
#   'lastUsage': 0,
#   'id': 'Encouragement to SM_1',
#   'usedNumber': 0,
#   'group': 9},
#  {'used': False,
#   'lastQuiz': False,
#   'priority': 1,
#   'id': 'Accepting pain_1',
#   'expiredate': 1688731778,
#   'usedNumber': 0,
#   'avoid': False,
#   'group': 10,
#   'lastUsage': 0,
#   'excluded': False,
#   'thisweek': False},
#  {'group': 12,
#   'expiredate': 1688731778,
#   'priority': 1,
#   'thisweek': False,
#   'excluded': False,
#   'used': False,
#   'avoid': False,
#   'lastUsage': 0,
#   'id': 'Attitude_3',
#   'lastQuiz': False,
#   'usedNumber': 0},
#  {'thisweek': False,
#   'used': False,
#   'expiredate': 1688731778,
#   'id': 'Distraction_1',
#   'usedNumber': 0,
#   'priority': 1,
#   'avoid': False,
#   'group': 14,
#   'lastQuiz': False,
#   'excluded': False,
#   'lastUsage': 0},
#  {'excluded': False,
#   'group': 16,
#   'lastQuiz': False,
#   'priority': 1,
#   'used': False,
#   'usedNumber': 0,
#   'avoid': False,
#   'thisweek': False,
#   'lastUsage': 0,
#   'id': 'Fear-avoidance_1',
#   'expiredate': 1688731778},
#  {'excluded': False,
#   'id': 'Thoughts_3',
#   'group': 18,
#   'lastQuiz': False,
#   'avoid': False,
#   'expiredate': 1688731778,
#   'lastUsage': 0,
#   'priority': 1,
#   'thisweek': False,
#   'usedNumber': 0,
#   'used': False},
#  {'used': False,
#   'excluded': False,
#   'lastQuiz': False,
#   'lastUsage': 0,
#   'avoid': False,
#   'expiredate': 1688731778,
#   'priority': 1,
#   'group': 19,
#   'id': 'Daily activity_1',
#   'thisweek': False,
#   'usedNumber': 0},
#  {'avoid': False,
#   'id': 'Me time_1',
#   'usedNumber': 0,
#   'lastQuiz': False,
#   'priority': 1,
#   'expiredate': 1688731778,
#   'used': False,
#   'group': 20,
#   'excluded': False,
#   'lastUsage': 0,
#   'thisweek': False},
#  {'lastUsage': 0,
#   'expiredate': 1688731778,
#   'id': 'Goal setting_1',
#   'priority': 1,
#   'avoid': False,
#   'excluded': False,
#   'thisweek': False,
#   'used': False,
#   'usedNumber': 0,
#   'lastQuiz': False,
#   'group': 27},
#  {'usedNumber': 0,
#   'group': 29,
#   'lastUsage': 0,
#   'excluded': False,
#   'id': 'Pacing_2',
#   'priority': 1,
#   'expiredate': 1688731778,
#   'avoid': False,
#   'lastQuiz': False,
#   'thisweek': False,
#   'used': False},
#  {'thisweek': False,
#   'expiredate': 1688731778,
#   'lastQuiz': False,
#   'lastUsage': 0,
#   'avoid': False,
#   'priority': 1,
#   'used': False,
#   'group': 30,
#   'excluded': False,
#   'id': 'Problem solving_1',
#   'usedNumber': 0},
#  {'thisweek': False,
#   'expiredate': 1688731778,
#   'id': 'Relaxation_1',
#   'lastQuiz': False,
#   'priority': 1,
#   'excluded': False,
#   'used': False,
#   'group': 31,
#   'avoid': False,
#   'lastUsage': 0,
#   'usedNumber': 0},
#  {'group': 32,
#   'thisweek': False,
#   'expiredate': 1688731778,
#   'lastUsage': 0,
#   'avoid': False,
#   'id': 'Sleep_1',
#   'excluded': False,
#   'used': False,
#   'lastQuiz': False,
#   'priority': 1,
#   'usedNumber': 0},
#  {'used': False,
#   'avoid': False,
#   'expiredate': 1688731778,
#   'group': 34,
#   'lastUsage': 0,
#   'thisweek': False,
#   'excluded': False,
#   'id': 'Family and friends_2',
#   'lastQuiz': False,
#   'priority': 1,
#   'usedNumber': 0},
#  {'id': '',
#   'usedNumber': 0,
#   'used': False,
#   'priority': 1,
#   'lastUsage': 0,
#   'excluded': False,
#   'thisweek': False,
#   'avoid': False,
#   'expiredate': 1688731778,
#   'lastQuiz': False}]

# %%
response=requests.post("http://localhost:30000/patient/plan/next",
                       headers={"Authorization": f"Bearer {token}"},
                       json={
                           "questionnaire":{
                                            "bt_pain_average": 4,
                                            "bt_pain_average_prev": 5,
                                            "t_cpg_function": 5,
                                            "t_cpg_function_prev": 5,
                                            "t_tampa_fear": 4,
                                            "bt_wai": 4,
                                            "t_sleep": "Sometimes",
                                            "bt_pseq_2item": 5,
                                            "bt_pss": 12,
                                            "bt_phq_2item": 2,
                                            "t_barriers": "too_tired",
                                            "used": ["potato"],
                                            "canbequiz": ["salad"],
                                            "thisweek":["Cause of LBP_5","Cause of LBP_4","Problem solving_4"]
                                            },
                            "exercise_duration":15
                       }
)
response.json()
# Out:
# [{'group': 13,
#   'usednumber': 0,
#   'thisweek': False,
#   'id': 'Changing negative thoughts_7',
#   'lastquiz': False,
#   'lastusage': 0,
#   'priority': 3,
#   'used': False,
#   'expiredate': 1595019975527.0},
#  {'lastQuiz': False,
#   'priority': 1,
#   'usedNumber': 0,
#   'avoid': False,
#   'thisweek': False,
#   'excluded': False,
#   'expiredate': 1688643584,
#   'lastUsage': 0,
#   'used': False,
#   'id': 'test_ex'},
#  {'expiredate': 1688643584,
#   'id': 'Cause of LBP_4',
#   'priority': 1,
#   'avoid': False,
#   'thisweek': False,
#   'group': 0,
#   'excluded': False,
#   'used': False,
#   'lastUsage': 0,
#   'usedNumber': 0,
#   'lastQuiz': False},
#  {'used': False,
#   'usedNumber': 0,
#   'expiredate': 1688643584,
#   'lastQuiz': False,
#   'priority': 1,
#   'lastUsage': 0,
#   'avoid': False,
#   'id': 'Guideline LBP_1',
#   'thisweek': False,
#   'excluded': False,
#   'group': 1},
#  {'excluded': False,
#   'thisweek': False,
#   'id': 'Pain rating_1',
#   'priority': 1,
#   'lastUsage': 0,
#   'avoid': False,
#   'expiredate': 1688643584,
#   'lastQuiz': False,
#   'used': False,
#   'group': 3,
#   'usedNumber': 0},
#  {'excluded': False,
#   'lastQuiz': False,
#   'priority': 1,
#   'group': 4,
#   'lastUsage': 0,
#   'usedNumber': 0,
#   'avoid': False,
#   'thisweek': False,
#   'id': 'Reassurance_4',
#   'used': False,
#   'expiredate': 1688643584},
#  {'used': False,
#   'avoid': False,
#   'lastUsage': 0,
#   'usedNumber': 0,
#   'group': 5,
#   'lastQuiz': False,
#   'excluded': False,
#   'priority': 1,
#   'expiredate': 1688643584,
#   'id': 'Stay active_1',
#   'thisweek': False}]

# %%
response=requests.post("http://localhost:8080/patient/plan/next",
                       json={"exercises_duration": 35},
                       headers={"Authorization": f"Bearer {token}"},
)
response.json()
# Out:
# {'timestamp': '2023-07-05T12:43:21.635+0000',
#  'status': 404,
#  'error': 'Not Found',
#  'message': 'No message available',
#  'path': '/patient/plan/next'}

# %%
response=requests.get("http://localhost:8080/concepts/Case/attributes",
                       
)
response.json()
# Out:
# {'Dem_age': 'IntegerDesc',
#  'T_tampa_fear': 'IntegerDesc',
#  'T_sleep': 'SymbolDesc',
#  'BT_PHQ_2item': 'IntegerDesc',
#  'F_GPE': 'IntegerDesc',
#  'Dem_bmi': 'FloatDesc',
#  'Dem_weight': 'FloatDesc',
#  'Pain_medication': 'SymbolDesc',
#  'Pain_self_efficacy': 'IntegerDesc',
#  'T_cpg_function': 'StringDesc',
#  'Education': 'SymbolDesc',
#  'EQ5D_selfcare': 'SymbolDesc',
#  'Primary_pain_site': 'SymbolDesc',
#  'BT_wai': 'IntegerDesc',
#  'Sleep_day': 'SymbolDesc',
#  'EQ5D_mobility': 'SymbolDesc',
#  'BIPQ_life': 'IntegerDesc',
#  'BIPQ_symptoms': 'IntegerDesc',
#  'Dem_gender': 'SymbolDesc',
#  'BT_PSS': 'IntegerDesc',
#  'BT_PSEQ_2item': 'IntegerDesc',
#  'BIPQ_pain_continuation': 'IntegerDesc',
#  'RMDQ': 'IntegerDesc',
#  'PSS': 'IntegerDesc',
#  'FABQ_lbp_cause': 'IntegerDesc',
#  'Comorbidities': 'SymbolDesc',
#  'BIPQ_concern': 'IntegerDesc',
#  'BIPQ_understanding': 'IntegerDesc',
#  'F_PASS': 'SymbolDesc',
#  'BIPQ_control': 'IntegerDesc',
#  'EQ5D_anxiety': 'SymbolDesc',
#  'SaltinGrimby': 'SymbolDesc',
#  'Activity_StepCount': 'StringDesc',
#  'T_barriers': 'SymbolDesc',
#  'PSFS_activity': 'SymbolDesc',
#  'BT_pain_average': 'StringDesc',
#  'MSKHQ': 'IntegerDesc',
#  'Pain_sites': 'SymbolDesc',
#  'SelfManagement_Exercise': 'SymbolDesc',
#  'Dem_height': 'FloatDesc',
#  'NDI': 'IntegerDesc',
#  'Pain_1year': 'SymbolDesc',
#  'Employment': 'SymbolDesc',
#  'PSFS_score': 'IntegerDesc',
#  'Sleep_wakeup': 'SymbolDesc',
#  'EQ5D_activity': 'SymbolDesc',
#  'Sleep_end': 'SymbolDesc',
#  'FABQ': 'IntegerDesc',
#  'BIPQ_selfmanagement': 'IntegerDesc',
#  'EQ5D_pain': 'SymbolDesc',
#  'BIPQ_emotion': 'IntegerDesc',
#  'Sleep_difficulty': 'SymbolDesc',
#  'PSFS_activity_name': 'StringDesc',
#  'Pain_worst': 'IntegerDesc',
#  'SelfManagement_Education': 'SymbolDesc',
#  'Work_characteristics': 'SymbolDesc',
#  'Family': 'SymbolDesc',
#  'EQ5D': 'IntegerDesc',
#  'SelfManagement_Activity': 'IntegerDesc'}

# %%
response=requests.get("http://localhost:8080/concepts/Case/amalgamationFunctions",
                       
)
response.json()
# Out:
# ['AllAtts',
#  'SMP_Exercise',
#  'exercise_sim',
#  'SMP_Activity',
#  'Global',
#  'SMP_Education']

# %%
response=requests.post("http://localhost:8080/concepts/Case/casebases/sbcases/amalgamationFunctions/SMP_Education/retrievalByMultipleAttributes",
                      json={
                          "Dem_gender":"female",
                      },
                      params={"k":-1}
)
response.json()[0]["SelfManagement_Education"].split(";")
# Out:
# {'similarity': '0.6428571428571429',
#  'caseID': 'FP_003',
#  'Activity_StepCount': '_unknown_',
#  'BIPQ_concern': '_unknown_',
#  'BIPQ_control': '_unknown_',
#  'BIPQ_emotion': '_unknown_',
#  'BIPQ_life': '_unknown_',
#  'BIPQ_pain_continuation': '_unknown_',
#  'BIPQ_selfmanagement': '_unknown_',
#  'BIPQ_symptoms': '_unknown_',
#  'BIPQ_understanding': '_unknown_',
#  'BT_PHQ_2item': '_unknown_',
#  'BT_PSEQ_2item': '_unknown_',
#  'BT_PSS': '_unknown_',
#  'BT_pain_average': '0:9;',
#  'BT_wai': '2',
#  'Comorbidities': '_unknown_',
#  'Dem_age': '54',
#  'Dem_bmi': '24.618076',
#  'Dem_gender': 'female',
#  'Dem_height': '178.0',
#  'Dem_weight': '78.0',
#  'EQ5D': '_unknown_',
#  'EQ5D_activity': '_unknown_',
#  'EQ5D_anxiety': '_unknown_',
#  'EQ5D_mobility': '_unknown_',
#  'EQ5D_pain': '_unknown_',
#  'EQ5D_selfcare': '_unknown_',
#  'Education': 'Above13',
#  'Employment': '_unknown_',
#  'FABQ': '_unknown_',
#  'FABQ_lbp_cause': '_unknown_',
#  'F_GPE': '_unknown_',
#  'F_PASS': '_unknown_',
#  'Family': 'spouse;',
#  'MSKHQ': '_unknown_',
#  'NDI': '_unknown_',
#  'PSFS_activity': '_unknown_',
#  'PSFS_activity_name': '_unknown_',
#  'PSFS_score': '2',
#  'PSS': '19',
#  'Pain_1year': '_unknown_',
#  'Pain_medication': 'Less than once a week',
#  'Pain_self_efficacy': '1',
#  'Pain_sites': 'Hips Thighs;Low Back;Knees;Elbows;Neck;',
#  'Pain_worst': '_unknown_',
#  'Primary_pain_site': '_unknown_',
#  'RMDQ': '8',
#  'SaltinGrimby': '_unknown_',
#  'SelfManagement_Activity': '_unknown_',
#  'SelfManagement_Education': 'Cause of LBP_1;Cause of LBP_2;Guideline LBP_1;Imaging_2;Pain rating_1;Reassurance_4;Reassurance_6;Reassurance_7;Stay active_1;Structure of back_2;Mind-body connection_1;Encouragement to SM_1;Encouragement to SM_5;Encouragement to SM_7;Accepting pain_1;Accepting pain_2;Attitude_3;Attitude_5;Distraction_1;Distraction_3;Distraction_4;Distraction_5;Fear-avoidance_1;Fear-avoidance_2;Fear-avoidance_3;Fear-avoidance_6;Thoughts_3;Thoughts_7;Daily activity_4;Daily activity_5;Me time_1;Me time_2;Goal setting_1;Goal setting_5;Pacing_2;Pacing_3;Pacing_6;Problem solving_1;Relaxation_1;Relaxation_3;Sleep_1;Sleep_2;Sleep_3;Work_2;Family and friends_4;Family and friends_5;',
#  'SelfManagement_Exercise': 'glut_01_01;back_01_01;ab_01_01;pain_01_02;',
#  'Sleep_day': 'Several times a week',
#  'Sleep_difficulty': 'Several times a week',
#  'Sleep_end': 'Several times a week',
#  'Sleep_wakeup': 'Several times a week',
#  'T_barriers': '_unknown_',
#  'T_cpg_function': '_unknown_',
#  'T_sleep': '_unknown_',
#  'T_tampa_fear': '9',
#  'Work_characteristics': 'Sitting'}

# %%
response=requests.get("http://localhost:8080/concepts/Case/casebases/sbcases/cases",
                       
)
response.json()

# %%
response=requests.post(
    "https://back-up.idi.ntnu.no/oauth/token",
    data={'grant_type': 'password',"username":"stuartFinal2","password":"cWbWaN6qgAVjhxdqqx5Ht"},
    verify=False,
    allow_redirects=False,
    auth=("my-trusted-client","secret")
)
print(response)
token=response.json()["access_token"]
response.json()
# Out:
# <Response [500]>
# /home/stuartgo/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'back-up.idi.ntnu.no'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 9
#       1 response=requests.post(
#       2     "https://back-up.idi.ntnu.no/oauth/token",
#       3     data={'grant_type': 'password',"username":"stuartFinal2","password":"cWbWaN6qgAVjhxdqqx5Ht"},
#    (...)
#       6     auth=("my-trusted-client","secret")
#       7 )
#       8 print(response)
# ----> 9 token=response.json()["access_token"]
#      10 response.json()
#
# KeyError: 'access_token'

# %%
response=requests.post("https://back-up.idi.ntnu.no//patient/plan/next",
                       json={"exercises_duration": 35},
                       headers={"Authorization": f"Bearer {token}"},
)
response.json()
