# %%
import requests

# %%
response=requests.post("http://localhost:30000/token",data={"username":"user","password":"secret"}
)
print(response)
token=response.json()["access_token"]
response.json()
# Out:
# <Response [200]>
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ1c2VyIiwiZXhwIjoxNjg3ODY1MzkzfQ.VO4rCZNPCQfSALqk6Vt1UbYefmjgRsPfh2sfZ_FDV5Y',
#  'token_type': 'bearer'}

# %%
response=requests.get("http://localhost:30000/data/exercise/list",
                       headers={"Authorization": f"Bearer {token}"},
)
response.json()
# Out:
# [{'_index': 'exercise',
#   '_id': 'P8LL-4gB2HOYjXxBWwmR',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'back_01_01',
#    'Title': 'Single leg lift',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': "Lie face down with your hands placed under your forehead to preserve the spine's neutral position. Stretch and lift one leg just above the floor, hold for 3-5 secs, then slowly lower the leg. Repeat with the other leg. ",
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Ettbensløft',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på mage med armene plassert under pannen for å sikre at ryggen er i nøytralstilling. Strekk og løft det ene benet litt opp fra gulvet og senk deretter benet rolig ned. Gjenta med det andre benet. '}},
#  {'_index': 'exercise',
#   '_id': 'QMLL-4gB2HOYjXxBWwmR',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'back_01_02',
#    'Title': 'Single arm lift',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': "Lie face down with your arms straight out in front of you and your forehead supported against the surface to preserve the spine's neutral position. Stretch and lift one arm just above the floor, hold it for 3-5 secs, then slowly lover the arm. Relax a moment before you repeat with the other arm. ",
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Enarmsløft',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på mage med armene strakt ut foran deg og med pannen hvilende på underlaget for å sikre at ryggen er i nøytralstilling. Strekk og løft en arm litt opp fra gulvet og senk deretter armen rolig ned. Gjenta med motsatt arm. '}},
#  {'_index': 'exercise',
#   '_id': 'QcLL-4gB2HOYjXxBWwmR',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'back_02_01',
#    'Title': 'Diagonal leg and arm lift',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': "Lie face down with your arms straight out in front of you and your forehead supported against the surface to preserve the spine's neutral position. Stretch and lift one arm and the opposite leg off the floor, hold for 3-5 secs and slowly lower them again. Relax a moment before you perform the exercise with the other arm and leg.",
#    'Level': 2.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Liggende diagonalløft',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på mage med armene strakt ut foran deg og med pannen hvilende på underlaget for å sikre at ryggen er i nøytralstilling. Strekk og løft en arm og motsatt ben opp fra gulvet og senk dem rolig ned igjen. Gjenta samme øvelse med motsatt arm og ben. '}},
#  {'_index': 'exercise',
#   '_id': 'QsLL-4gB2HOYjXxBWwmR',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'back_02_02',
#    'Title': 'Upper body lift',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': 'Lie face down, arms by your side and look into the mat/floor during the whole exercise. Activate the muscles at the bottom of your pelvis and buttocks then pull both shoulder blades in towards your spine. While keeping this position, inhale, stretch your fingers towards your feet and lift your torso and arms just off the floor. Hold this position for 3-5 seconds then return to the starting position. Exhale and relax before repeating the exercise. ',
#    'Level': 2.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Rygghev',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på mage med armene langs siden og se ned i gulvet gjennom hele øvelsen. Aktiver bekkenbunn- og setemusklene og trekk begge skulderbladene inn mot ryggsøylen.  Strekk fingrene ned mot føttene og løft overkroppen og armene opp fra gulvet. Hold stillingen i 1-2 sekunder, for så å gå tilbake til utgangsposisjon.  '}},
#  {'_index': 'exercise',
#   '_id': 'Q8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'back_03_01',
#    'Title': 'Rotation upper body',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': 'Lie face down with your forehead resting on the surface, your elbows bent and your hands placed by your ears. Lift your left arm, shoulder and head off the surface and rotate towards the left by looking upwards and to the side, hold for 3-5 secs, return to start. Perform the exercise to the right. ',
#    'Level': 3.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Rotasjon av overkropp',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på mage med hendene under pannen. Løft skuldre, armer og hode opp fra underlaget og roter mot venstre ved at du ser oppover og mot siden. Hold stilingen i 2-3 sekunder, for så å gå tilbake til utgangsposisjon. Gjør så øvelsen mot høyre. '}},
#  {'_index': 'exercise',
#   '_id': 'RMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'back_03_02',
#    'Title': 'Double leg lift',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': 'Lie face down with your arms by your side and the soles of your feet turned upward. Lift your legs off the floor and hold for 3-5 secs. Rest for 3-5 secs.',
#    'Level': 3.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Dobbelt benløft',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på mage med armene langs siden og med fotsålene vendt oppover. Aktiver sete- og lårmuskulatur og løft benene opp fra gulvet, hold stillingen i 2-3 sekunder, og langsomt senk dem ned i gjen.'}},
#  {'_index': 'exercise',
#   '_id': 'RcLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'back_04_01',
#    'Title': 'Upper body lift with arm swing',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': 'Lie face down with your hands placed under your forehead. Squeeze your buttocks together, activate your back muscles and lift . your upper body and arms off the floor. Move your arms  forward and back above your head once while holding the position in the trunk, then lower your upper body to the floor. Repeat the exercise.',
#    'Level': 4.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Rygghev med armsving',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på mage med hendene plassert under pannen. Press setemusklene sammen, aktiver ryggmusklene og løft overkroppen og armene opp fra gulvet.  Beveg armene frem og tilbake over hodet mens du fortsatt holder overkroppen løftet, og senk deretter overkroppen ned til gulvet. '}},
#  {'_index': 'exercise',
#   '_id': 'RsLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'back_04_02',
#    'Title': 'Elbow-supported pelvis-lift',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back, supporting your upper body on your elbows. LIFT your pelvis off the floor so that your body forms a straight line, hold the position for 3-5 secs, lower your pelvis and then rest for 3-5 secs.',
#    'Level': 4.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Albuestøttet bekkenløft',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen og støtt overkroppen med albuene bøyd og underarmene i gulvet. Løft bekkenet opp fra gulvet slik at kroppen blir strak, hold stillingen i 2-3 sekunder. Senk bekkenet og hold pause i 2-3 sekunder. '}},
#  {'_index': 'exercise',
#   '_id': 'R8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'back_05_01',
#    'Title': 'Swimming',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': 'Lie face down with your arms straight in front of you. Lift your left heel towards the ceiling and stretch your right fingertips in front of you, breathe in and activate the muscles around your stomach by pulling the belly button towards the spine at the same time as you lift the right arm and left leg. Breathe out and go back to the starting position, then repeat with the other arm and opposite leg.',
#    'Level': 5.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Svømming',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på mage med hendene under pannen. Strekk armene fremover langs gulvet. Trekk pusten og aktiver magemusklene ved å trekke navlen inn mot ryggsøylen samtidig som du løfter armer og ben. Løft vekselvis din høyre og venstre hæl opp mot taket, mens du strekker fingrene på motsatt arm fromover. Gjør denne bevegelsen i 2-3 sekunder, pust ut og gå tilbake til utgangsstilling. Hold 2-3 sekunders pause før du gjentar øvelsen.'}},
#  {'_index': 'exercise',
#   '_id': 'SMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'back_05_02',
#    'Title': 'Bend leg lift',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': 'Lie face down with your arms by your side and knees bent at 90 degrees. Activate the muscles in your buttocks and lift your knees off from the floor towards the ceiling. Hold for 3-5 secs then slowly lower the knees. Rest 3-5 secs. ',
#    'Level': 5.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Benløft med bøyd kne',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på mage med armene langs siden og knærne bøyd 90 grader. Aktiver setemuskulaturen og løft knærne opp fra gulvet. Hold stillingen i 2-3 sekunder, senk så knærne rolig ned.'}},
#  {'_index': 'exercise',
#   '_id': 'ScLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'back_06_01',
#    'Title': 'Diagonal leg-arm lift',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': 'Start on all fours. Activate the muscles around your stomach and lower back by pulling the belly button in towards the spine without bending your back to keep you stable, lift the right arm and extend it forward and lift the opposite leg and extend it backwards, hold for 3-5 secs, slowly lower leg and arms. Relax a moment before repeating with other arm and opposite leg.',
#    'Level': 6.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Firfotstående diagonalløft ',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Start på alle fire. Aktiver musklene i magen og nedre del av ryggen ved å trekke navlen inn mot ryggsøylen uten å bøye ryggen for å holde deg stabil. Løft høyre arm og strekk den fremover, løft venstre ben og strekk det bakover. Hold stillingen i 2-3 sekunder, og senk deretter armen og benet rolig ned. Gjenta øvelsen med motsatt arm og ben.'}},
#  {'_index': 'exercise',
#   '_id': 'SsLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'back_06_02',
#    'Title': 'Diagonal leg-arm lift, angled ',
#    'Explanation': 'This exercise will strengthen your back muscles',
#    'Instruction (template: starting position. Movement, end position)': 'Start on all fours with hips in a 45 degree angle. Activate the muscles around your stomach and lower back by pulling the belly button in towards the spine without bending your back. Lift the right arm and extend it forward and lift the opposite leg and extend it backwards. Lower the arm and leg and relax a moment before repeating with the opposite arm and leg.',
#    'Level': 6.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Firfotstående diagonalløft i vinkel',
#    'Type.1': 'Back',
#    'Forklaring': 'Denne øvelsen vil styrke ryggmusklene dine',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Start på alle fire. Aktiver musklene i magen og nedre del av ryggen ved å trekke navlen inn mot ryggsøylen uten å bøye ryggen. Løft høyre arm og strekk den fremover, løft motsatt ben og strekk det bakover. Flytt den strekte armen og benet ca 45 grader ut til siden, hold i 1-2 sekunder før du tar dem tilbake igjen. Senk armen og benet, og hold en liten pause før du gjentar øvelsen med motsatt arm og ben. '}},
#  {'_index': 'exercise',
#   '_id': 'S8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'glut_01_01',
#    'Title': 'Hip stability',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with knees bent and feet on the floor. Activate the muscles in your stomach and buttocks to keep you stable. One leg should stay steady while the other knee is moved to the side and back in a slow motion. Your pelvis must be kept steady during the exercise. Repeat with opposite leg. ',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Hoftestabilitet',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med knærne bøyd og føttene i gulvet. Aktiver musklene i magen og setet for å holde deg stabil. Det ene benet skal stå fast mens det andre kneet beveges ut til siden og tilbake i en langsom bevegelse. Bekkenet skal holdes stabilt gjennom hele øvelsen. Gjenta med motsatt ben.'}},
#  {'_index': 'exercise',
#   '_id': 'TMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'glut_01_02',
#    'Title': 'Pelvis lift',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with your knees bent and feet on the floor. Activate the muscles in your buttocks and lift your pelvis and lower back off the floor, hold for 3-5 sec, thenslowly lower your pelvis. Rest for 3-5 sec.',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Bekkenløft',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med knærne bøyd og føttene i gulvet. Aktiver setemusklene og løft bekkenet og korsryggen opp fra gulvet og senk langsomt ned igjen. '}},
#  {'_index': 'exercise',
#   '_id': 'TcLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'glut_02_01',
#    'Title': 'Side-lying hip rotation ',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your side with your hips and knees slightly bent, supporting your head with one hand. Slowly lift the upper knee while keeping your feet together, then lower the knee back to starting position. After 10  repetitions, repeat lying on the opposite side.',
#    'Level': 2.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Sideliggende hofterotasjon',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på siden med lett bøyd hofte og kne, og støtt hodet med den ene hånden. Løft det øverste kneet rolig opp mot taket mens du holder føttene samlet. Senk kneet tilbake til utgangsposisjon.  Etter 10 repetisjoner gjentar du øvelsen på motsatt side.'}},
#  {'_index': 'exercise',
#   '_id': 'TsLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'glut_02_02',
#    'Title': 'Bridge position bent kene lift',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with bent knees and feet on the floor. Activate the muscles in your buttocks and lift your pelvis and lower back off the floor, hold the position and raise one leg from the floor and move it towards your body. Hold this position for 3-5 secs then slowly lower the leg and then your back and pelvis. Repeat lifting the opposite leg.',
#    'Level': 2.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Bekkenløft med ett ben',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med knærne bøyd og føttene i gulvet. Aktiver setemusklene og løft bekkenet opp fragulvet, hold stillingen og løft ett ben fra gulvet og trekk kneet mot kroppen.  Holdstillingen i 2-3 sekunder og senk deretter benet, ryggen ogbekkenet. Gjenta øvelsen med motsatt ben. '}},
#  {'_index': 'exercise',
#   '_id': 'T8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'glut_03_01',
#    'Title': 'Hip stability',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your side with both legs slightly bent towards you and your head supported by your hands. Lift the upper leg a little so it is not touching the lower leg , slowly move the knee towards the chest and then backwards as far as possible, then return to the starting position. Relax a moment before performing another repetition. Complete one set before repeating to the other side. ',
#    'Level': 3.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Hoftestabilitet',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på siden med hofte og kne lett bøyd mot deg og støtt hodet med hendene. Løft det øverste benet slik at det akkurat ikke berører den nederste benet. Trekk kneet opp mot brystet også tilbake til utgangsstilling. Gjør ferdig ett sett før du bytter side. '}},
#  {'_index': 'exercise',
#   '_id': 'UMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'glut_03_02',
#    'Title': 'Pelvis lift w/knee extension',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with knees bent and  feet on the floor. Activate the muscles in your buttocks and lift your pelvis and lower back off the floor, hold the position and straighten one leg, while still keeping your knees together. Hold that position for 3-5 secs, return to starting position by bending your knee so your foot is back on the floor and then slowly lower your back and pelvis to the floor. Repeat with the opposite leg.',
#    'Level': 3.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Bekkenløft med knestrekk',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med knærne bøyd og føttene i gulvet. Aktiver setemusklene og løft bekken og korsrygg opp fra gulvet, hold stillingen og strekk det ene kneet med tærne pekende oppover, mens du holder knærne samlet. Hold stillingen i 2-3 sekunder, og gå tilbake til utgangsstilling ved å bøye kneet slik at foten igjen plasseres på gulvet og senk så bekkenet. Gjenta øvelsen med motsatt ben.'}},
#  {'_index': 'exercise',
#   '_id': 'UcLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'glut_04_01',
#    'Title': 'Side plank on knees',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your side with legs bent, supporting yourself with your elbow (arm nearest floor). Activate the muscles around your back and stomach and lift your pelvis off the floor, hold for 3-5 secs, then lower your pelvis to starting position.',
#    'Level': 4.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Sideplanke på kne',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på siden med knærne bøyd, og støtt overkroppen  med nederste albue i gulvet. Aktiver rygg- og magemuskler og løft bekkenet opp fra gulvet, og senk bekkenet ned til gulvet igjen. '}},
#  {'_index': 'exercise',
#   '_id': 'UsLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'glut_04_02',
#    'Title': 'Pelvis lift single leg',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with your arms BY your side and both legs straight. Bend one knee and place the foot on the floor. Activate the muscles in your buttocks and LIFT your pelvis, lower back and straight leg off the floor until you have a straight line through your body from shoulder to knee. Hold the position 3-5 secs and then lower your back, pelvis and straight leg to the floor. Repeat with opposite leg. ',
#    'Level': 4.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Ettbens bekkenløft',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med armene ned langs siden og begge benene strakt ut. Bøy ett ben og plasser foten på gulvet. Aktiver setemusklene og løft bekken, korsrygg og det strake benet opp fra gulvet slik at kroppen holder en rett linje fra skulder til fot. Hold stillingen i 2-3 sekunder og senk bekken, korsrygg og ben ned på gulvet igjen. Gjenta med motsatt ben. '}},
#  {'_index': 'exercise',
#   '_id': 'U8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'glut_05_01',
#    'Title': 'Sideways plank on elbows',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your side, supporting yourself with your elbow (arm nearest floor), keeping your body and legs straight with one foot in front of the other. Lift your hips towards the ceiling and keep your back and legs straight, hold the position for 3-5 secs, return to the starting position. Repeat to the opposite side.',
#    'Level': 5.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Sideplanke på albue',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på siden og støtt kroppen med nederste albue i gulvevt. Hold kroppen rett med den ene foten forann den andre. Løft hoften opp mot taket og hold ryggen og benene strake, og senk hoften ned igjen mot gulvet.  Gjenta øvelsen på motsatt side. '}},
#  {'_index': 'exercise',
#   '_id': 'VMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'glut_05_02',
#    'Title': 'Pelvis lift with legs on chair',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with your arms crossed in front of your chest and your legs on a chair with hips and knees bent. Activate the muscles around your stomach and lift your pelvis and lower back off the floor as fas as you can or until only your shoulders are touching the floor, hold for  3-5 secs, then slowly lower your back and pelvis to the starting position.',
#    'Level': 5.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Bekkenløft på stol',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med armene i kryss over brystet og føttene på en stol med bøyde knær. Aktiver magemusklene og løft bekken og korsrygg så høyt du kan helt til kun skuldrene berører gulvet. Hold stillingen i 2-3 sekunder, og senk så kroppen langsomt ned til utgansstilling. '}},
#  {'_index': 'exercise',
#   '_id': 'VcLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'glut_06_01',
#    'Title': 'Side plank w/rotation',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your side, supporting yourself with your elbow (arm nearest floor), keeping your body and legs straight and one foot in front of the other. Lift your hips towards the ceiling keeping your back and legs straight, then move your upper arm and body towards the floor to create rotation, return to the starting position and stretch your arm up towards the ceiling, then lower your hips. Relax for moment before you repeat to the other side.',
#    'Level': 6.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Sideplanke med rotasjon',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på siden og støtt kroppen med nederste albue i gulvet. Hold kroppen rett med den ene foten foran den andre. Senk den øverste armen og kroppen ned mot gulvet for å skape en rotasjon. Returner til utgangsstilling. Hold en liten pause før du repeterer på motsatt side. '}},
#  {'_index': 'exercise',
#   '_id': 'VsLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'glut_06_02',
#    'Title': 'Leg lift, bridge position',
#    'Explanation': 'This exercise targets the hip abductor muscles. These are essential for supporting your lower back while walking and standing.',
#    'Instruction (template: starting position. Movement, end position)': 'With your back facing the floor, support yourself on your hands and feet while holding your pelvis raised towards the ceiling. Raise one foot and extend your knee. Hold the position for 3-5 secs and return to the start position. Repeat with your opposite leg.',
#    'Level': 6.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Brostående med benløft',
#    'Type.1': 'Glut',
#    'Forklaring': 'Denne øvelsen styrker utoverførerne i hofteleddet. Disse musklene er nødvendige for å støtte korsryggen når man går og står.',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Stå på alle fire med ryggen vendt ned mot gulvet, og hold bekkenet løftet. Løft en fot og strekk  kneet. Hold stililngen i 2-3 sekunder og returner til utgangsstilling. Gjenta øvelsen med motsatt ben. '}},
#  {'_index': 'exercise',
#   '_id': 'V8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'ab_01_01',
#    'Title': 'Legs from side to side',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back, knees bent, feet on the floor and arms stretched out to the side. Lift your feet a few centimeters from the floor, keeping your back and arms on the floor. Turn your pelvis and knees to the right and then to the left.',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Ben fra side til side',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med bøyde knær, føttene på gulvet og med armene ut til siden. Løft føttene noen få cm over gulvet, med ryggen og armene fortsatt i gulvet. Roter bekkenet og knærne til høyre og så til venstre. '}},
#  {'_index': 'exercise',
#   '_id': 'WMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'ab_01_02',
#    'Title': 'One-leg stretch',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back, knees bent, feet on the floor and arms stretched out to the side. Keeping your back and arms on the floor, activate the muscles around your stomach and stretch one leg out straight while the opposite leg it still bent with the foot on the floor. Return to starting position and repeat with other leg. ',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Ettbensstrekk',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med knærne bøyd, føttene på gulvet og med armene ut til siden. Aktiver magemusklene mens du holder ryggen og armene i gulvet, og strekk ett ben mens motsatt ben fortsatt er bøyd med foten i gulvet. Returner til utgangsstilling og gjenta med motsatt ben.'}},
#  {'_index': 'exercise',
#   '_id': 'WcLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'ab_02_01',
#    'Title': 'Sit-ups',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with knees bent and arms pointing towards your feet. Activate the muscles around your stomach, breath out and raise your upper body and arms while keeping your lower back against the floor. Keep your upper body raised while breathing in and return to starting position while breathing out again.',
#    'Level': 2.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Sit-ups',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med knærne bøyd og armene ned langs siden. Aktiver magemusklene, trekk inn haken og løft øvre del av kroppen og armene opp fra underlaget mens du holder nedre del av ryggen i gulvet. Løft overkroppen og armene lengre opp fra underlaget ved å strekke armene mot føttene. Rull sakte tilbake igjen før du gjentar øvelsen. '}},
#  {'_index': 'exercise',
#   '_id': 'WsLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'ab_02_02',
#    'Title': 'Alternate one-leg stretches',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with your hips and knees bent at 90 degree angles and arms touching the sides of your stomach. To keep your lower back in contact with the surface, activate the muscles of your stomach and straighten one leg while the other leg is held in the 90 degree angle, return to starting position. Relax before repeating with the other leg.',
#    'Level': 2.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Alternativ ettbensstrekk',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med hoftene og knærne i 90 grader, og med armene langs siden. Aktiver magemusklene for å holde korsryggen i kontakt med underlaget, og strekk et ben mens det andre bene holdes i 90 grader. Returner langsomt tilbake til utgangsstilling. Hold en liten pause før du gjentar med motsatt ben.  '}},
#  {'_index': 'exercise',
#   '_id': 'W8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'ab_03_01',
#    'Title': 'Crunch',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with your knees bent and your feet on the floor, hands at your ears. Lift your head, arms and upper body, so that only your lower back is in contact with the floor, hold for 2-3 secs, slowly lower back down. Try to move smoothly.',
#    'Level': 3.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Crunch',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med knæren bøyd, føttene på gulvet, og hendene inntil ørene. Løft hodet, armene og overkroppen slik at kun korsryggen er i kontakt med gulvet, og senk rolig overkroppen ned igjen. Prøv å ha en jevn bevegelse. '}},
#  {'_index': 'exercise',
#   '_id': 'XMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'ab_03_02',
#    'Title': 'Oblique crunch',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with knees bent, feet on the floor and arms by your side. Raise your head and upper body and rotate by stretching one arm towards the opposite knee while you keep your lower back in contact with the floor throughout the movement. Hold for 2-3 secs, then slowly lower body, arms and head. Relax a moment before repeating on the other side.',
#    'Level': 3.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Oblique crunch/skrå crunch',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med knærne bøyd, føttene i gulvet og armene langs siden. Løft og roter hodet og overkroppen ved å strekke den ene armen over mot motsatt kne mens du fortsatt har korsryggen i kontakt med underlaget. Senk langsomt armen, overkroppen og hodet. Gjenta til motsatt side. '}},
#  {'_index': 'exercise',
#   '_id': 'XcLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'ab_03_03',
#    'Title': 'Bike movements',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with your knees bent at 90 degree angles and raised above your hips with arms by your sides. Move your legs as if your were riding a bike. ',
#    'Level': 3.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Sykling',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med knær og hofte bøyd 90 grader og armene langs siden. Beveg benene som om du syklet. Sykle 10 ganger med hvert ben for å fullføre ett set. '}},
#  {'_index': 'exercise',
#   '_id': 'XsLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'ab_04_01',
#    'Title': 'Lying pelvis rotation',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with your knees bent at 90 degree angles and raised above your hips with your arms slightly to the sides. Activate the muscles around your stomach and lower back and then rotate your lower body from side to side in a controlled motion.',
#    'Level': 4.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Liggende bekkenrotasjon',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med hofte og kne i 90 grader og armene litt ut fra kroppen. Aktiver musklene rundt mage og korsrygg, og roter nedre del av kroppen ved å bevege knærne fra side til side i en kontrollert bevegelse.  '}},
#  {'_index': 'exercise',
#   '_id': 'X8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'ab_04_02',
#    'Title': 'Lying pelvis rotation 2',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with your arms slightly to the side, legs out straight. Activate the muscles around your stomach and lower back, raise one leg straight and point it towards the opposite hand by rotating the lower back, slowly return to starting position. Repeat withother leg. ',
#    'Level': 4.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Liggende bekkenrotasjon 2',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med armene litt ut fra kroppen, og benene strake. Aktiver musklene rundt mage og korsrygg, hold det ene benet strakt og løft det opp i luften og pekende mot motsatt arm ved å rotere nedre del av ryggen. Returner til utgangsstilling og gjenta med motsatt ben. Du kan øke vanskelighetsgraden ved å gjøre øvelsen i veldig langsomt tempo eller ved å hold stillingen mens du er rotert til sidene. '}},
#  {'_index': 'exercise',
#   '_id': 'YMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'ab_04_03',
#    'Title': 'Lying straight leg lift',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with legs out straight and arms by your sides. Activate the muscles around your stomach and back, and pull your knees up toward your chest while keeping your back on the floor, stop when your reach a 90 degree angle at your hip.',
#    'Level': 4.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Lying straight leg lift',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med strakte ben og armene langs siden. Aktiver musklene rundt mage og rygg og trekk knærne opp mot brystet mens korsryggen fortsatt har kontakt med underlaget. Stop når du har ca 90 graders vinkel i hoftene. Strekk langsomt benene igjen mens du holder føttene opp fra gulvet, før du gjentar øvelsen. '}},
#  {'_index': 'exercise',
#   '_id': 'YcLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'ab_05_01',
#    'Title': 'Oblique sit-up',
#    'Explanation': 'This exercise targets abdominal muscles that in combination with your back muscles support your spine when moving, standing or lifting',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with your hips and knees bent at 90 degree angles, supporting your head with your hands. Activate the muscles around your stomach so that your lower back stays in contact with the floor. Lift your upper body from the floor and twist, so your elbow touches the opposite knee. Complete all repetitions to one side or alternate between sides.',
#    'Level': 5.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Skrå sit-up',
#    'Type.1': 'Ab',
#    'Forklaring': 'Denne øvelsen styrker magemusklene som i kombinasjon med ryggmusklene, er med til å støtte ryggsøylen når man beveger seg, står oppreist eller løfter. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med hofte og kne i 90 grader, og støtt hodet med hendene. Aktiver magemusklene slik at korsryggen har kontakt med underlaget. Løft overkroppen fra gulvet og roter slik at albuen nærmer seg motsatt kne. Hold motsatt arm i kontakt med underlaget for bedre stabilitet. Gjenta alle repetisjonene til en side, eller skift side for hver gang.  '}},
#  {'_index': 'exercise',
#   '_id': 'YsLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'ab_05_02',
#    'Title': 'Dead Bug',
# ...
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Stå med litt avstand mellom føttene, hendene på hoften, hofte og knær lett bøyd og bekkenet i nøytralstilling. Vipp bekkenet fremover for å svaie i korsryggen, returner til nøytralstilling og vipp bekkenet videre bakover slik at korsryggen er helt flat.'}},
#  {'_index': 'exercise',
#   '_id': 'ecLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'pain_03_03',
#    'Title': 'Standing high knee lift',
#    'Explanation': 'Gentle movement of the joints and muscles in your back can help to relieve pain. It also helps you to explore what you can and cannot do.',
#    'Instruction (template: starting position. Movement, end position)': 'Stand on the spot and raise one leg so that your knee and hip are bent at a 90 degree angle. Alternate between the right and left leg. ',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Høye kneløft',
#    'Type.1': 'Pain relief',
#    'Forklaring': 'Myke bevegelser i ledd og muskler i ryggen kan hjelpe for å lette på smertene. Det kan også hjelpe deg med å finne ut hva du kan og ikke kan gjøre. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Stå med litt avstand mellom knær og føtter. Hold fast i en stolrygg for støtte og balanse. Løft ett ben slik at kneet og hoften bøyes ca 90 grader. Løft vekselvis høyre og venstre ben. Øk vanskelighetsgraden ved å gjøre øvelsen uten støtte fra en stol. Øvelsen bør gjøres i en langsom bevegelse.  '}},
#  {'_index': 'exercise',
#   '_id': 'esLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'pain_04_01',
#    'Title': 'Standing rotation of the Torso',
#    'Explanation': 'Gentle movement of the joints and muscles in your back can help to relieve pain. It also helps you to explore what you can and cannot do.',
#    'Instruction (template: starting position. Movement, end position)': 'Stand with your hands folded under your chin with elbows pointing to the sides. Slowly rotate your upper body from side to side. Your gaze should follow the movement. ',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Stående rotasjon',
#    'Type.1': 'Pain relief',
#    'Forklaring': 'Myke bevegelser i ledd og muskler i ryggen kan hjelpe for å lette på smertene. Det kan også hjelpe deg med å finne ut hva du kan og ikke kan gjøre. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Stå med armene foldet på brystet og albuene ut til siden. Roter overkroppen sakte fra side til side. Blikket skal følge bevegelsen. '}},
#  {'_index': 'exercise',
#   '_id': 'e8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'pain_04_02',
#    'Title': 'Picking pears',
#    'Explanation': 'Gentle movement of the joints and muscles in your back can help to relieve pain. It also helps you to explore what you can and cannot do.',
#    'Instruction (template: starting position. Movement, end position)': 'Stand with your arms at your sides. Slowly rotate your upper body to the right and stretch your left arm up and back. Switch sides.',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Picking pears',
#    'Type.1': 'Pain relief',
#    'Forklaring': 'Myke bevegelser i ledd og muskler i ryggen kan hjelpe for å lette på smertene. Det kan også hjelpe deg med å finne ut hva du kan og ikke kan gjøre. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Stå med litt avstand mellom føttene og armene i siden. Roter overkroppen langsomt mot høyre og løft og strekk venstre arm opp og bakover som om du prøver å rekke opp til noe over hodet ditt. Gjenta til motsatt side. '}},
#  {'_index': 'exercise',
#   '_id': 'fMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_source': {'ExerciseID': 'flex_01_01',
#    'Title': 'Lying bend and arch',
#    'Explanation': 'This exercise will help to increase the flexibility of your back so that you can move your back more freely',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your knees and forearms: slide backwards, bend your back by moving your hips towards your heels and then forward to stretched arms and sway in your lower back.',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Liggende bøy og svai',
#    'Type.1': 'Flexibility',
#    'Forklaring': 'Denne øvelsen vil øke bevegeligheten i ryggen, og gjøre at du kan bevege deg mer fritt. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Len deg på knærne og hendene. Gli bakover ved å bevege hoftene bak mot hælene, beveg deg frem igjen til utgangsstilling også senker du bekkenet ned mot gulvet mens du strekker armene slik at du får en svai i ryggen. '}},
#  {'_index': 'exercise',
#   '_id': 'fcLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'flex_01_02',
#    'Title': 'Seated bend and arch',
#    'Explanation': 'This exercise will help to increase the flexibility of your back so that you can move your back more freely',
#    'Instruction (template: starting position. Movement, end position)': 'Sit on a chair with your arms resting on your thighs and knees well apart. Slide your hands along the inside of your thighs and shins to bend forward as far as possible, hold the final position for 1-2 secs and slowly return to the starting position. Try to bend further down with each repetition. ',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Sittende fremoverbøying',
#    'Type.1': 'Flexibility',
#    'Forklaring': 'Denne øvelsen vil øke bevegeligheten i ryggen, og gjøre at du kan bevege deg mer fritt. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Sit på en stol med armene hvilende på lårene og avstand mellom knærne. La hendene skli langs innsiden av lårene og leggene mens du bøyer deg så langt frem som mulig. Returner langsomt til utgangsstilling. Prøv å kom lengre frem for hver gang. '}},
#  {'_index': 'exercise',
#   '_id': 'fsLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'flex_01_03',
#    'Title': 'Standing bending by wall',
#    'Explanation': 'This exercise will help to increase the flexibility of your back so that you can move your back more freely',
#    'Instruction (template: starting position. Movement, end position)': 'Stand 30-50 cm from a wall, with forearms resting on the wall in front of your face. Push your pelvis towards the wall. Turn around and stand with your back against the wall. Bend forward slowly until your hands are at your knees, while activating your stomach muscles. Return to the starting position again. ',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Stående ryggstrekk  mot vegg',
#    'Type.1': 'Flexibility',
#    'Forklaring': 'Denne øvelsen vil øke bevegeligheten i ryggen, og gjøre at du kan bevege deg mer fritt. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Stå ca 1 meter fra en vegg, men hendene hvilende på veggen i brysthøyde. Press bekkenet mot veggen. Beveg langsomt bekkenet tilbake til utgangsstilling. '}},
#  {'_index': 'exercise',
#   '_id': 'f8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'flex_01_04',
#    'Title': 'Standing bend and arch',
#    'Explanation': 'This exercise will help to increase the flexibility of your back so that you can move your back more freely',
#    'Instruction (template: starting position. Movement, end position)': 'Hold a standing position with your weight evenly dIstributed between your feet. Bend forwards as far as possible, return to the standing position and continue the motion backwards with your hands on your lower back/buttocks to create a slight arch of the back while looking at the ceiling. ',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Stående bøy og strekk',
#    'Type.1': 'Flexibility',
#    'Forklaring': 'Denne øvelsen vil øke bevegeligheten i ryggen, og gjøre at du kan bevege deg mer fritt. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Stå med vekten jevnt fordelt på begge benene. Bøy deg fremover så langt du kan, kom tilbake til utgangsstilling og fortsett bevegelsen bakover med hodet ved å se opp mot taket slik at du får en svai i ryggen. Hvis du er usikker på å gjøre øvelsen uten støtte kan du bruke veggen til støtte mens du gjør bevegelsen. '}},
#  {'_index': 'exercise',
#   '_id': 'gMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'flex_01_05',
#    'Title': 'Back of thigh stretch',
#    'Explanation': 'This exercise will help to increase the flexibility of your back so that you can move your back more freely',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back with one leg out straight, pointing towards the ceiling. Place your hands behind the other knee (leg straight) and pull the leg toward you until you feel a stretch in your buttock muscles and the muscles at the back of your thigh (hamstrings). Hold for 30 secs and then change legs.',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Tøying av baklår',
#    'Type.1': 'Flexibility',
#    'Forklaring': 'Denne øvelsen vil øke bevegeligheten i ryggen, og gjøre at du kan bevege deg mer fritt. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med ett ben strakt opp mot taket. Plasser hendene dine bak låret og trekk benet mot deg helt til du kjenner strekk i setemusklene og i musklene i baklåret. Hold i 30 sekunder før du skifter ben.'}},
#  {'_index': 'exercise',
#   '_id': 'gcLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'flex_01_06',
#    'Title': 'Back of thigh and calf stretch',
#    'Explanation': 'This exercise will help to increase the flexibility of your back so that you can move your back more freely',
#    'Instruction (template: starting position. Movement, end position)': 'Stand with your hands on your sides, slightly bend one knee and straighten the other out slightly in front. On the straight leg, point your toes up towards your body and slowly lower your upper body forward until you feel a stretch at the back of your leg. Avoid bending your back! Hold for 30 secs and change legs.',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Tøying av baklår og legg',
#    'Type.1': 'Flexibility',
#    'Forklaring': 'Denne øvelsen vil øke bevegeligheten i ryggen, og gjøre at du kan bevege deg mer fritt. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Stå med hendene i siden med ett ben lett bøyd og det andre strakt ut fremover. Pek tærne oppover med det forrerste benet og senk overkroppen langsomt nedover slik at du kjenner strekk på baksiden av benet. Unngå å bøye ryggen din! Hold i 30 sekunder før du bytter ben.  '}},
#  {'_index': 'exercise',
#   '_id': 'gsLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'flex_01_07',
#    'Title': 'Hip bender stretch',
#    'Explanation': 'This exercise will help to increase the flexibility of your back so that you can move your back more freely',
#    'Instruction (template: starting position. Movement, end position)': 'Lean on one bent knee on the floor. Place your hands at the sides of your waist and push your hips forward until you feel the front of your hips stretch. Hold the position. Return to starting position and repeat. It is important to keep your back straight during the exercise. ',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Tøying av hoftebøyer',
#    'Type.1': 'Flexibility',
#    'Forklaring': 'Denne øvelsen vil øke bevegeligheten i ryggen, og gjøre at du kan bevege deg mer fritt. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Stå med det ene kneet i gulvet og det andre benet foran deg med foten i gulvet og kneet i ca 90 grader. Plasser hendene i siden og press hoften fremover slik at du kjenner strekk på fremsiden av hofteleddet. Hold stillingen i 30 sekunder før du skifter ben. Det er viktig at ryggen holdet rett i denne øvelsen. '}},
#  {'_index': 'exercise',
#   '_id': 'g8LL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruction (template: starting position. Movement, end position).keyword',
#    'Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'flex_01_08',
#    'Title': 'Buttock stretch',
#    'Explanation': 'This exercise will help to increase the flexibility of your back so that you can move your back more freely',
#    'Instruction (template: starting position. Movement, end position)': 'Sit on the floor with a straight back, one leg out straight and the other leg bent at the knee and crossed over the straight leg. Hold your knee with both hands, and pull it towards the opposite shoulder until your feel a stretch in the muscles around your buttocks. Maintain a swayed back throughout the stretch. Hold for 30 secs and then switch legs.',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Tøying av setemuskler',
#    'Type.1': 'Flexibility',
#    'Forklaring': 'Denne øvelsen vil øke bevegeligheten i ryggen, og gjøre at du kan bevege deg mer fritt. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Sitt på gulvet med så rett rygg som mulig, ett ben strakt og det andre benet bøyd over det strake benet. Hold fast i det bøyde kneet med innsiden av albuen fra samme side mens motsatt arm holder fast i håndleddet. Trekk kneet langsomt mot motsatt skulder helt til du kjenner strekk i setemusklene. Hold i 30 sekunder før du skifter ben. '}},
#  {'_index': 'exercise',
#   '_id': 'hMLL-4gB2HOYjXxBWwmS',
#   '_score': 1.0,
#   '_ignored': ['Instruksjon (template: starting posistion. Movement, end position).keyword'],
#   '_source': {'ExerciseID': 'flex_01_09',
#    'Title': 'Lower back rotation stretch',
#    'Explanation': 'This exercise will help to increase the flexibility of your back so that you can move your back more freely',
#    'Instruction (template: starting position. Movement, end position)': 'Lie on your back, bend the hips and knees and rotate them to the left side. Raise the right arm up above your head and feel a stretch on the side of your upper body and lower back. Hold for 30 secs and repeat to the other side.',
#    'Level': 1.0,
#    'Reps': 10.0,
#    'Sets': 3.0,
#    'Time': 5.0,
#    'Tittel': 'Tøying av nedre rygg',
#    'Type.1': 'Flexibility',
#    'Forklaring': 'Denne øvelsen vil øke bevegeligheten i ryggen, og gjøre at du kan bevege deg mer fritt. ',
#    'Instruksjon (template: starting posistion. Movement, end position)': 'Ligg på ryggen med bøyde hofter og knær og med føttene på gulvet. Roter til venstre ved å trekke knærne til siden med venstre arm, og løft høyre arm over hodet. Her skal du kjenne at det strekker langs siden av overkroppen og i korsryggen. Hold i 30 sekunder før du skifter side.  '}}]

# %%
response=requests.post("http://localhost:30000/patient/plan/next",
                       json={"exercises_duration": 35},
                       headers={"Authorization": f"Bearer {token}"},
)
response.json()
# Out:
# {'detail': 'Missing questionannaire'}

# %%
response=requests.post(
    "https://back-up.idi.ntnu.no/oauth/token",
    data={'grant_type': 'password',"username":"stuartFinal2","password":"cWbWaN6qgAVjhxdqqx5Ht"},
    verify=False,
    allow_redirects=False,
    auth=("my-trusted-client","secret")
)
print(response)
token=response.json()["access_token"]
response.json()
# Out:
# <Response [500]>
# /home/stuartgo/new_selfback/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'back-up.idi.ntnu.no'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 9
#       1 response=requests.post(
#       2     "https://back-up.idi.ntnu.no/oauth/token",
#       3     data={'grant_type': 'password',"username":"stuartFinal2","password":"cWbWaN6qgAVjhxdqqx5Ht"},
#    (...)
#       6     auth=("my-trusted-client","secret")
#       7 )
#       8 print(response)
# ----> 9 token=response.json()["access_token"]
#      10 response.json()
#
# KeyError: 'access_token'

# %%
response=requests.post("https://back-up.idi.ntnu.no//patient/plan/next",
                       json={"exercises_duration": 35},
                       headers={"Authorization": f"Bearer {token}"},
)
response.json()
